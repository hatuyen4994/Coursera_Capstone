# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ## Section 1: Introduction/Business Problem

# %% [markdown]
# Introduction where you discuss the business problem and who would be interested in this project.

# %% [markdown]
# #### A friend of mine wants to open a cinema in Paris.
# He thinks that the first important thing about opening a cinema is its location and the surrounding neighborhood. He asked me to find some possible locations to open a cinema in Paris and wants me to concentrate on the selection of cinema location instead of cinema facility and rental price.
#
# He explained that in customer point of view, watching movie is a part of whole afternoon or night activities. Cinema should has **many restaurants and shopping places nearby**. Transportation is also an important factor. Customer can walk to cinema within **5 minutes** from **public transport facilities** such as bus stop and metro station.
#
# I first need to select **5 possible locations** to build the cinema. Then I will find out which location should be suggested to my friend.

# %% [markdown]
# ## Section 2: Data

# %% [markdown]
# Data where you describe the data that will be used to solve the problem and the source of the data.

# %% [markdown]
# According to the question, I need to find following data to resolve the problem.

# %% [markdown]
# ### 1. Geographic coordinate of Paris cinemas
#
# I need to **compare 5 possible locations with current cinemas** in Paris. Therefore, I need to find a list of Paris cinema and cinemas' geographic coordinates. I will scrape the data from this website and come up with a list of cinemas in Paris http://www.allocine.fr/salle/cinemas-pres-de-115755/.

# %%
#Import neccesary libraries
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import folium

# %%
#define a function to extract the name and address of the cinemas on the website
#this function will scrape the web for meta data and extract the name and address of all the cinemas include in an url
def get_cinemas(soup):
    cinemas = soup.find_all('div', class_='theaterblock j_entity_container')
    list_cinemas = []
    for i,cinema in enumerate(cinemas):
        name = cinemas[i].h2.text.strip()
        address = cinemas[i].p.text.strip()
        list_cinemas.append({
            'name':name,
            'address':address
        })
    return list_cinemas

# %%
#run the function to scraping the data from the website
endpoint = 'http://www.allocine.fr/salle/cinemas-pres-de-115755/?page={}'
list_cinemas = []
for page in range(1,33): #the information about paris cinemas is included in 32 page the website
    url = endpoint.format(str(page))
    print(url)
    source = requests.get(url)
    soup = bs(source.text, 'lxml')
    list_cinemas += get_cinemas(soup)
    print('Page', page)
# Out:
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=1
# Page 1
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=2
# Page 2
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=3
# Page 3
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=4
# Page 4
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=5
# Page 5
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=6
# Page 6
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=7
# Page 7
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=8
# Page 8
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=9
# Page 9
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=10
# Page 10
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=11
# Page 11
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=12
# Page 12
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=13
# Page 13
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=14
# Page 14
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=15
# Page 15
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=16
# Page 16
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=17
# Page 17
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=18
# Page 18
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=19
# Page 19
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=20
# Page 20
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=21
# Page 21
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=22
# Page 22
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=23
# Page 23
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=24
# Page 24
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=25
# Page 25
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=26
# Page 26
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=27
# Page 27
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=28
# Page 28
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=29
# Page 29
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=30
# Page 30
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=31
# Page 31
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=32
# Page 32

# %%
# take a look at the result
list_cinemas
# Out:
# [{'name': 'Luminor Hôtel de Ville\nRéservation sur Allociné',
#   'address': '20, rue du Temple 75004 Paris 4e arrondissement'},
#  {'name': 'Espace Saint-Michel',
#   'address': '7, place Saint-Michel 75005 Paris 5e arrondissement'},
#  {'name': 'Studio Galande',
#   'address': '42, rue Galande 75005 Paris 5e arrondissement'},
#  {'name': 'Centre Georges-Pompidou',
#   'address': 'pl. Georges-Pompidou 75004 Paris 4e arrondissement\nMétro Hotel-de-Ville, Rambuteau.'},
#  {'name': 'Saint-André des Arts',
#   'address': '30 rue Saint-André-des-Arts: caisse, salles 1 & 2 - 12 rue Gît-le-Cœur, Salle 3 75006 Paris 6e arrondissement'},
#  {'name': 'MK2 Odéon (Côté St Michel)',
#   'address': '7, rue Hautefeuille 75006 Paris 6e arrondissement'},
#  {'name': 'MK2 Beaubourg',
#   'address': '50, rue Rambuteau 75003 Paris 3e arrondissement'},
#  {'name': 'Christine 21',
#   'address': '4, rue Christine 75006 Paris 6e arrondissement'},
#  {'name': 'Le Champo - Espace Jacques Tati',
#   'address': '51, rue des Ecoles 75005 Paris 5e arrondissement'},
#  {'name': 'Nouvel Odéon',
#   'address': "6, rue de l'Ecole-de-Medecine 75006 Paris 6e arrondissement"},
#  {'name': 'Forum des images',
#   'address': 'Forum des Halles, 2 rue du Cinéma 75001 Paris 1er arrondissement'},
#  {'name': 'UGC Odéon',
#   'address': '124, bd Saint-Germain 75006 Paris 6e arrondissement'},
#  {'name': 'Ecoles 21',
#   'address': '23, rue des Ecoles 75005 Paris 5e arrondissement'},
#  {'name': 'UGC Ciné Cité Les Halles',
#   'address': '7, place de la Rotonde 75001 Paris 1er arrondissement'},
#  {'name': 'Reflet Medicis',
#   'address': '3 rue Champollion 75005 Paris 5e arrondissement'},
#  {'name': 'Filmothèque du Quartier Latin',
#   'address': '9, rue Champollion 75005 Paris 5e arrondissement'},
#  {'name': 'UGC Danton',
#   'address': '99, bd Saint-Germain 75006 Paris 6e arrondissement'},
#  {'name': 'MK2 Odéon (Côté St Germain)',
#   'address': '113, bd Saint-Germain 75006 Paris 6e arrondissement'},
#  {'name': 'Le Grand Action',
#   'address': '5, rue des Ecoles 75005 Paris 5e arrondissement'},
#  {'name': 'Studio Luxembourg Accattone',
#   'address': '20 rue Cujas 75005 Paris 5e arrondissement'},
#  {'name': 'Les 3 Luxembourg',
#   'address': '67, rue Monsieur-le-Prince 75006 Paris 6e arrondissement'},
#  {'name': 'Cinéma du Panthéon',
#   'address': '13, rue Victor-Cousin 75005 Paris 5e arrondissement'},
#  {'name': 'MK2 Bastille (côté Beaumarchais)',
#   'address': '4, boulevard Beaumarchais 75011 Paris 11e arrondissement'},
#  {'name': "L'Arlequin",
#   'address': '76 rue de Rennes 75006 Paris 6e arrondissement'},
#  {'name': 'Majestic Bastille',
#   'address': '4 boulevard Richard Lenoir 75011 Paris 11e arrondissement'},
#  {'name': 'Studio des Ursulines',
#   'address': '10, rue des Ursulines 75005 Paris 5e arrondissement'},
#  {'name': 'MK2 Bastille (côté Fg St Antoine)',
#   'address': '5, rue du Faubourg-Saint-Antoine 75011 Paris 11e arrondissement'},
#  {'name': 'Epée de Bois',
#   'address': '100, rue Mouffetard 75005 Paris 5e arrondissement\nMétro Censier-Daubenton.'},
#  {'name': "L'Archipel - PARIS CINE\nRéservation sur Allociné",
#   'address': '17 bd de Strasbourg 75010 Paris 10e arrondissement'},
#  {'name': 'Le Grand Rex\nRéservation sur Allociné',
#   'address': '1, bd Poissonniere 75002 Paris 2e arrondissement'},
#  {'name': 'Max Linder Panorama\nRéservation sur Allociné',
#   'address': '24, bd Poissonniere 75009 Paris 9e arrondissement'},
#  {'name': 'Le Brady Cinema & Théâtre\nRéservation sur Allociné',
#   'address': '39, bd de Strasbourg 75010 Paris 10e arrondissement'},
#  {'name': 'UGC Lyon Bastille',
#   'address': '12, rue de Lyon 75012 Paris 12e arrondissement'},
#  {'name': 'Lucernaire\nRéservation sur Allociné',
#   'address': '53, rue Notre-Dame-des-Champs 75006 Paris 6e arrondissement'},
#  {'name': 'MK2 Parnasse',
#   'address': '11, rue Jules Chaplain 75006 Paris 6e arrondissement'},
#  {'name': 'UGC Opéra',
#   'address': '32, bd des Italiens 75009 Paris 9e arrondissement'},
#  {'name': 'Gaumont Opéra (côté Premier)',
#   'address': '32, rue Louis Legrand 75002 Paris 2e arrondissement'},
#  {'name': 'Gaumont Opéra (côté Français)',
#   'address': '38, bd des Italiens 75009 Paris 9e arrondissement'},
#  {'name': 'Gaumont Opéra (côté Capucines)',
#   'address': '2, bd des Capucines - 38, bd des Italiens - 32, rue Louis Legrand 75009 Paris 9e arrondissement'},
#  {'name': 'Escurial',
#   'address': '11 boulevard de Port Royal 75013 Paris 13e arrondissement'},
#  {'name': 'UGC Rotonde',
#   'address': '103, bd du Montparnasse 75006 Paris 6e arrondissement'},
#  {'name': 'Sept Parnassiens\nRéservation sur Allociné',
#   'address': '98, bd du Montparnasse 75014 Paris 14e arrondissement\nMétro Vavin.'},
#  {'name': 'UGC Montparnasse',
#   'address': '83, bd du Montparnasse 75006 Paris 6e arrondissement'},
#  {'name': 'Bretagne\nRéservation sur Allociné',
#   'address': '73, bd du Montparnasse 75006 Paris 6e arrondissement'},
#  {'name': 'Gaumont Parnasse',
#   'address': "3, rue d'Odessa 75014 Paris 14e arrondissement"},
#  {'name': 'Gaumont Parnasse côté Montparnos',
#   'address': "16 Rue d'Odessa 75014 Paris 14e arrondissement"},
#  {'name': 'Gaumont Les Fauvettes',
#   'address': '58, av. des Gobelins 75013 Paris 13e arrondissement'},
#  {'name': 'Fondation Jerome Seydoux - Pathé',
#   'address': '73 avenue des Gobelins 75013 Paris 13e arrondissement'},
#  {'name': 'UGC Gobelins',
#   'address': '66bis, av. des Gobelins 75013 Paris 13e arrondissement'},
#  {'name': 'UGC Gobelins',
#   'address': '66bis, av. des Gobelins 75013 Paris 13e arrondissement'},
#  {'name': 'Les Cinq Caumartin\nRéservation sur Allociné',
#   'address': '101, rue Saint-Lazare 75009 Paris 9e arrondissement'},
#  {'name': 'Cinéma Chaplin Denfert\nRéservation sur Allociné',
#   'address': '24, place Denfert-Rochereau 75014 Paris 14e arrondissement'},
#  {'name': 'MK2 Grand Palais',
#   'address': "A l'intérieur du Grand Palais: à l'angle du Cours de la Reine et de l'Avenue Winston-Churchill / Entrée par les marches de la Rotonde Alexandre 3, à côté du restaurant Mini Palais. 75008 Paris 8e arrondissement"},
#  {'name': 'Le Louxor - Palais du cinéma\nRéservation sur Allociné',
#   'address': '170 Boulevard de Magenta 75010 Paris 10e arrondissement'},
#  {'name': 'La Cinémathèque française',
#   'address': '51 rue de Bercy 75012 Paris 12e arrondissement'},
#  {'name': 'MK2 Bibliothèque',
#   'address': '128-162 avenue de France 75013 Paris 13e arrondissement'},
#  {'name': 'Gaumont Alésia',
#   'address': '73, av. du Gal-Leclerc 75014 Paris 14e arrondissement'},
#  {'name': "Lieu Secret - L'Entrepôt",
#   'address': '7-9, rue Francis-de-Pressense 75014 Paris 14e arrondissement'},
#  {'name': 'MK2 Quai de Loire',
#   'address': '7 quai de Loire 75019 Paris 19e arrondissement'},
#  {'name': 'Gaumont Champs-Elysées - Marignan',
#   'address': '27-33 avenue des Champs-Elysées 75008 Paris 8e arrondissement'},
#  {'name': 'Le Cinéma des Cinéastes',
#   'address': '7, av. de Clichy 75017 Paris 17e arrondissement'},
#  {'name': 'Pathé Wepler',
#   'address': '140, bd de Clichy et 8, av de Clichy 75018 Paris 18e arrondissement'},
#  {'name': 'Cinéma Studio 28',
#   'address': '10, rue Tholoze 75018 Paris 18e arrondissement'},
#  {'name': 'MK2 Quai de Seine',
#   'address': '14, quai de la Seine 75019 Paris 19e arrondissement'},
#  {'name': 'UGC Ciné Cité Bercy',
#   'address': '2, cour Saint-Emilion 75012 Paris 12e arrondissement'},
#  {'name': 'Elysées Lincoln\nRéservation sur Allociné',
#   'address': '14, rue Lincoln 75008 Paris 8e arrondissement'},
#  {'name': 'MK2 Gambetta',
#   'address': '6, rue Belgrand 75020 Paris 20e arrondissement'},
#  {'name': 'Cinéma Chaplin Saint Lambert\nRéservation sur Allociné',
#   'address': '6, rue Peclet 75015 Paris 15e arrondissement'},
#  {'name': 'UGC Normandie',
#   'address': '116Bis, Avenue des Champs-Elysées 75008 Paris 8e arrondissement'},
#  {'name': 'Le Balzac\nRéservation sur Allociné',
#   'address': '1, rue Balzac 75008 Paris 8e arrondissement'},
#  {'name': 'UGC George V',
#   'address': '146, av. des Champs-Elysees 75008 Paris 8e arrondissement'},
#  {'name': 'UGC George V',
#   'address': '146, av. des Champs-Elysees 75008 Paris 8e arrondissement'},
#  {'name': 'Publicis Cinémas\nRéservation sur Allociné',
#   'address': '129, av. des Champs-Elysees 75008 Paris 8e arrondissement'},
#  {'name': 'Gaumont Convention',
#   'address': '27, rue Alain-Chartier 75015 Paris 15e arrondissement'},
#  {'name': "Pathé Quai d'Ivry IMAX",
#   'address': '2, quai Marcel Boyer 94200 Ivry-sur-Seine'},
#  {'name': "Club de l'Etoile\nRéservation sur Allociné",
#   'address': '14 rue troyon 75017 Paris 17e arrondissement'},
#  {'name': 'Mac-Mahon',
#   'address': '5, av. Mac-Mahon 75017 Paris 17e arrondissement'},
#  {'name': 'Majestic Passy',
#   'address': '18 rue de Passy 75016 Paris 16e arrondissement'},
#  {'name': 'Pathé Beaugrenelle',
#   'address': '7 rue Linois 75015 Paris 15e arrondissement'},
#  {'name': 'CGR Paris Lilas\nRéservation sur Allociné',
#   'address': 'Place du maquis du Vercors 75020 Paris 20e arrondissement'},
#  {'name': 'Cinéma Marcel-Pagnol', 'address': '17 rue Béranger 92240 Malakoff'},
#  {'name': "Cin'Hoche", 'address': '6, rue Hoche 93170 Bagnolet'},
#  {'name': 'UGC Ciné Cité Paris 19',
#   'address': '166, boulevard Mac Donald 75019 Paris 19e arrondissement'},
#  {'name': 'Pathé La Villette',
#   'address': '30 avenue Corentin Cariou 75019 Paris 19e arrondissement'},
#  {'name': 'Mégarama Arcueil',
#   'address': '8 av du Président Allende 94110 Arcueil'},
#  {'name': 'Le Luxy', 'address': '77, av. Georges-Gosnat 94200 Ivry-sur-Seine'},
#  {'name': 'UGC Maillot',
#   'address': 'porte Maillot, Palais des Congres 75017 Paris 17e arrondissement\nMétro Porte-Maillot'},
#  {'name': 'Pathé Levallois So Ouest',
#   'address': "Centre commercial So Ouest - 28, rue d'Alsace 92300 Levallois-Perret"},
#  {'name': 'Cinéma du Garde-Chasse',
#   'address': '181 bis rue de Paris 93260 Les Lilas'},
#  {'name': 'Espace 1789',
#   'address': '2-4, rue Alexandre-Bachelet 93400 Saint-Ouen'},
#  {'name': 'Cinéma De Vanves', 'address': '12, rue Sadi-Carnot 92170 Vanves'},
#  {'name': 'Ciné 104', 'address': '104, av. Jean-Lolive 93500 Pantin'},
#  {'name': 'Gaumont Aquaboulevard',
#   'address': '8-16, rue du Colonel-Pierre-Avia 75015 Paris 15e arrondissement'},
#  {'name': 'Théâtre-Cinéma Victor Hugo',
#   'address': '14, Avenue Victor Hugo 92220 Bagneux'},
#  {'name': 'Espace municipal Jean Vilar',
#   'address': '1, rue Paul Signac 94110 Arcueil'},
#  {'name': 'Le Vincennes', 'address': '30 avenue de Paris 94300 Vincennes'},
#  {'name': 'Rutebeuf', 'address': '16-18 allee Gambetta 92110 Clichy'},
#  {'name': 'Le Studio',
#   'address': '2, rue Edouard-Poisson 93300 Aubervilliers'},
#  {'name': "Ciné d'Issy",
#   'address': "11-13 rue Danton/mail Menand Métro Mairie d'Issy conservatoire de musique 92130 Issy-les-Moulineaux"},
#  {'name': 'La Pleiade', 'address': '12, av. Cousin-de-Mericourt 94230 Cachan'},
#  {'name': 'Le Village', 'address': '4, rue de Chezy 92200 Neuilly-sur-Seine'},
#  {'name': 'Georges Méliès',
#   'address': '12, place Jean-Jaurès 93100 Montreuil'},
#  {'name': "Cinéma d'Art Romain Rolland",
#   'address': '18 rue Eugène Varlin 94800 Villejuif'},
#  {'name': 'Le Trianon', 'address': 'Place Carnot 93230 Romainville'},
#  {'name': 'Le Trianon', 'address': 'Place Carnot 93230 Romainville'},
#  {'name': "L'Alcazar",
#   'address': '1, rue de la Station 92600 Asnières-sur-Seine'},
#  {'name': 'Cinéma de Châtillon',
#   'address': '7bis, rue de la Mairie 92320 Châtillon'},
#  {'name': 'Abel Gance', 'address': '184, bd. Saint-Denis 92400 Courbevoie'},
#  {'name': 'Les 3 Cinés - Robespierre',
#   'address': '19, avenue Maximilien Robespierre 94400 Vitry-sur-Seine'},
#  {'name': 'Pôle Culturel',
#   'address': '82, rue Marcel Bourdarias 94140 Alfortville'},
#  {'name': 'Gaumont Stade de France',
#   'address': '8, rue du Mondial-1998 93200 Saint-Denis'},
#  {'name': 'Pathé Boulogne',
#   'address': '26, rue Le Corbusier 92100 Boulogne-Billancourt'},
#  {'name': 'Cinéma Landowski',
#   'address': '28, av. Andre-Morizet 92100 Boulogne-Billancourt'},
#  {'name': 'Théâtre Claude Debussy',
#   'address': '116 avenue du Général de Gaulle 94700 Maisons-Alfort'},
#  {'name': 'La Tournelle', 'address': "14, rue Dispan 94240 L' Haÿ-les-Roses"},
#  {'name': "L'Etoile", 'address': '1, allee du Progres 93120 La Courneuve'},
#  {'name': 'Le Kosmos',
#   'address': '243 ter, av. de la Republique 94120 Fontenay-sous-Bois'},
#  {'name': 'Mégarama Villeneuve-la-Garenne',
#   'address': '44 Avenue de la Longue Bertrane 92390 Villeneuve-la-Garenne'},
#  {'name': 'Salle Jean-Renoir',
#   'address': '7 Villa des Aubépines 92270 Bois-Colombes'},
#  {'name': 'Le Central', 'address': '136 rue de la République 92800 Puteaux'},
#  {'name': "L'Ecran", 'address': "14 passage de l'Aqueduc 93200 Saint-Denis"},
#  {'name': 'Cinéma Le Capitole\nRéservation sur Allociné',
#   'address': '3, rue Ledru-Rollin 92150 Suresnes'},
#  {'name': 'UGC Ciné Cité La Défense',
#   'address': 'Le Dôme - Centre commercial Les 4 Temps 92092 Paris - La Défense'},
#  {'name': 'UGC Ciné Cité La Défense',
#   'address': 'Le Dôme - Centre commercial Les 4 Temps 92092 Paris - La Défense'},
#  {'name': 'Jean-Vigo',
#   'address': '1, rue Pierre-et-Marie-Curie 92230 Gennevilliers'},
#  {'name': 'Magic Cinéma',
#   'address': 'Centre commercial 2, Rue du Chemin-Vert 93000 Bobigny'},
#  {'name': 'Théâtre André Malraux',
#   'address': '102, av. du General-de-Gaulle 94550 Chevilly-Larue'},
#  {'name': "Centre d'art et de culture",
#   'address': '15, boulevard des Nations Unies 92190 Meudon'},
#  {'name': 'Trianon', 'address': '3 bis, rue Marguerite-Renaudin 92330 Sceaux'},
#  {'name': 'Les Trois Pierrots',
#   'address': '6, rue du Mont-Valerien 92210 Saint-Cloud'},
#  {'name': 'Centre culturel Andre-Malraux',
#   'address': '10, av. Francis-de-Pressense 93350 Le Bourget'},
#  {'name': "L'Hélios", 'address': '35, rue du Bournard 92700 Colombes'},
#  {'name': 'Ciné Gérard-Philipe',
#   'address': '1 place Jane Rhodes 92350 Le Plessis-Robinson'},
#  {'name': 'Ciné Gérard-Philipe',
#   'address': '1 place Jane Rhodes 92350 Le Plessis-Robinson'},
#  {'name': 'Ciné-Sel', 'address': '47-49 Grande-Rue 92310 Sèvres'},
#  {'name': 'Cinémas du palais, Armand-Badéyan',
#   'address': '40, allee Parmentier 94000 Créteil'},
#  {'name': 'Royal Palace',
#   'address': '165, grande rue Charles-de-Gaulle 94130 Nogent-sur-Marne'},
#  {'name': 'Espace Culturel du Parc',
#   'address': '120 rue Sadi Carnot 93700 Drancy'},
#  {'name': 'Cinéma André-Malraux',
#   'address': '25, cours de la Republique 93140 Bondy'},
#  {'name': 'Théâtre-Cinéma Paul-Eluard',
#   'address': '4, av. de Villeneuve-Saint-Georges 94600 Choisy-le-Roi'},
#  {'name': 'Pathé Thiais - Belle Epine',
#   'address': 'Centre commercial Belle-Epine 94320 Thiais'},
#  {'name': 'Ariel - Hauts de Rueil',
#   'address': '58 avenue de Fouilleuses 92500 Rueil-Malmaison'},
#  {'name': 'Espace Culturel Robert Doisneau',
#   'address': '16 avenue du Maréchal de Lattre de Tassigny 92360 MEUDON LA FORET'},
#  {'name': 'UGC Ciné Cité Créteil',
#   'address': 'Centre commercial -Soleil 94000 Créteil'},
#  {'name': 'CGR Epinay-sur-Seine\nRéservation sur Allociné',
#   'address': '5, avenue Joffre 93800 Épinay-sur-Seine'},
#  {'name': 'Centre des Bords-de-Marne',
#   'address': '2, rue de la Prairie 94170 Le Perreux-sur-Marne'},
#  {'name': 'Le Lido',
#   'address': '70, av. de la Republique 94100 Saint-Maur-des-Fossés'},
#  {'name': 'Le Sélect\nRéservation sur Allociné',
#   'address': '10, avenue de la Division Leclerc 92160 Antony'},
#  {'name': 'La Fauvette',
#   'address': '21, av. Daniel-Perdrige 93360 Neuilly-Plaisance'},
#  {'name': 'Le Rex\nRéservation sur Allociné',
#   'address': '364, av. de la Division-Leclerc 92290 Châtenay-Malabry'},
#  {'name': 'Les Lumières', 'address': '49, rue Maurice-Thorez 92000 Nanterre'},
#  {'name': 'Ciné Garches', 'address': '86 Grand-Rue 92380 Garches'},
#  {'name': 'Le Colombier',
#   'address': "Place Charles de Gaulle 92410 Ville-d'Avray"},
#  {'name': 'La Lucarne', 'address': '100, rue Juliette Savar 94000 Créteil'},
#  {'name': 'Centre culturel Le Figuier blanc',
#   'address': '16-18 Rue Grégoire Collas 95100 Argenteuil'},
#  {'name': 'Studio 66',
#   'address': '66, rue Jean-Jaures 94500 Champigny-sur-Marne'},
#  {'name': 'Cinéma Jean Gabin',
#   'address': '12/14 boulevard Léon-Feix 95100 Argenteuil'},
#  {'name': "L'Atrium", 'address': '3, parvis Robert-Schuman 92370 Chaville'},
#  {'name': 'UGC Vélizy 2',
#   'address': 'Centre commercial Velizy II 78140 Vélizy-Villacoublay'},
#  {'name': 'Ariel - Centre ville',
#   'address': '97-99 av. Paul-Doumer 92500 Rueil-Malmaison'},
#  {'name': 'Louis-Daquin',
#   'address': '16, mail Debre Berhan - Place Gabriel Péri 93150 Le Blanc-Mesnil'},
#  {'name': 'Espace des Arts - Salle Philippe Noiret',
#   'address': '144 avenue Jean Jaurès 93320 Les Pavillons-sous-Bois'},
#  {'name': 'Espace Bernard Mantienne',
#   'address': "3 voie de l'Aulne 91370 Verrières-le-Buisson"},
#  {'name': 'Salle Aragon-Triolet',
#   'address': '1, Place Gaston Viens 94310 Orly'},
#  {'name': 'UGC Enghien Le Français',
#   'address': '38, rue du Général de Gaulle 95880 Enghien-les-Bains'},
#  {'name': 'Centre des Arts',
#   'address': '12-16 rue de la Libération 95880 Enghien-les-Bains'},
#  {'name': 'Les Toiles',
#   'address': 'place Francois-Truffaut 95210 Saint-Gratien'},
#  {'name': 'Ecrans Eluard',
#   'address': '162, rue Maurice-Berteaux 95870 Bezons'},
#  {'name': 'Jacques Brel',
#   'address': "1, place de l'Hotel-de-Ville 95140 Garges-lès-Gonesse"},
#  {'name': 'Théatre Andre-Malraux',
#   'address': '1bis, rue Guillemeteau 93220 Gagny'},
#  {'name': 'Théâtre et Cinéma Jacques-Prevert',
#   'address': '134 avenue Anatole-France 93600 Aulnay-sous-Bois'},
#  {'name': 'Cinéma 4 Delta',
#   'address': '81bis av. du Bac 94210 La Varenne-Saint-Hilaire'},
#  {'name': 'Normandy', 'address': '72, bd de la Republique 92420 Vaucresson'},
#  {'name': 'CGR My Place', 'address': '2, allée Henri Dunant 95200 Sarcelles'},
#  {'name': 'Cinémassy', 'address': 'pl. de France 91300 Massy'},
#  {'name': 'UGC Ciné Cité Noisy-le-Grand',
#   'address': 'Centre commercial les Arcades 93160 Noisy-le-Grand'},
#  {'name': 'Le Casino',
#   'address': '13, rue Guillaume Budé 94350 Villiers-sur-Marne'},
#  {'name': 'Louis-Jouvet\nRéservation sur Allociné',
#   'address': '3, place Maurice-Berteaux 78400 Chatou'},
#  {'name': "UGC Ciné Cité O'Parinor",
#   'address': 'Centre commercial O’Parinor Le Haut de Galy 93600 Aulnay-sous-Bois'},
#  {'name': 'Le Bijou\nRéservation sur Allociné',
#   'address': '4 place de la libération 93160 Noisy-le-Grand'},
#  {'name': "Cinéma l'Eden",
#   'address': '5 bis rue de Pontoise 95160 Montmorency'},
#  {'name': 'Espace Jean-Marie Poirier',
#   'address': '1 esplanade du 18 juin 1940 94370 Sucy-en-Brie'},
#  {'name': 'Le Forum',
#   'address': 'Place du Forum (Quartier de la Haie-Griselle) 94470 Boissy-Saint-Léger'},
#  {'name': 'Pathé Massy', 'address': '21, Place du Grand Ouest 91300 Massy'},
#  {'name': "L'Avant-Scène",
#   'address': "78-80 avenue d'Alsace Lorraine 91550 Paray-Vieille-Poste"},
#  {'name': 'Cinéma Pierre Fresnay',
#   'address': '3, rue Saint-Flaive prolongée 95120 Ermont'},
#  {'name': 'Cinéma Yves-Montand',
#   'address': '36, rue Eugene-Masse 93190 Livry-Gargan'},
#  {'name': 'Cinéma Jean-Marais', 'address': '59, bd. Carnot 78110 Le Vésinet'},
#  {'name': 'Cinéma Ventura',
#   'address': '4, rue Samuel-Desbordes 91200 Athis-Mons'},
#  {'name': 'Salle Le Cormier',
#   'address': '123 Rue de Saint Germain 95240 Cormeilles-en-Parisis'},
#  {'name': 'Etoile Cosmos\nRéservation sur Allociné',
#   'address': '22, av. de la Resistance 77500 Chelles'},
#  {'name': 'Espace Paul-Valery',
#   'address': '72-74 av. Ardouin 94420 Le Plessis-Trévise'},
#  {'name': "L'Atalante",
#   'address': '48, rue du Prieuré 78600 Maisons-Laffitte'},
#  {'name': 'Cinéma Varda', 'address': '37-39 Grande-Rue 91260 Juvisy-sur-Orge'},
#  {'name': 'Le Fontenelle', 'address': 'Place de la Gare 78160 Marly-le-Roi'},
#  {'name': 'Le Cyrano', 'address': '114, av. de la Republique 91230 Montgeron'},
#  {'name': 'Paradiso', 'address': '2 rue Marc-Sangnier 91330 Yerres'},
#  {'name': 'Cinema Jacques-Tati',
#   'address': '29bis av. du general-de-Gaulle 93290 Tremblay-en-France'},
#  {'name': 'Mégarama Montigny les Cormeilles',
#   'address': '82 boulevard Victor Bordier 95370 Montigny-lès-Cormeilles'},
#  {'name': 'Cinéma Domont', 'address': '12, allee Sainte-Therese 95330 Domont'},
#  {'name': 'Calypso', 'address': '38, rue Victor-Basch 91170 Viry-Châtillon'},
#  {'name': 'EuropaCorp CINEMAS',
#   'address': '30 rue des Buissons - Centre commercial Aéroville 95700 Roissy-en-France'},
#  {'name': 'Cinéma Apollo',
#   'address': '62, av. de la Republique 77340 Pontault-Combault'},
#  {'name': 'La Ferme du buisson', 'address': 'allee de la Ferme 77186 Noisiel'},
#  {'name': 'Les Varietes',
#   'address': '72, rue de Chelles 77360 Vaires-sur-Marne'},
#  {'name': 'Espace/MJC Jacques-Tati',
#   'address': '14, av. Saint-Laurent 91400 Orsay'},
#  {'name': 'Théâtre Sarah-Bernhardt',
#   'address': '82, boulevard Paul Vaillant Couturier 95190 Goussainville'},
#  {'name': 'Pandora',
#   'address': '6, allee Simone-Signoret (place du marche) 78260 Achères'},
#  {'name': 'C2L Poissy', 'address': 'place de la République 78300 Poissy'},
#  {'name': 'UGC Ciné Cité SQY Ouest',
#   'address': '1 avenue de la Source de la Bievre 78180 Montigny-le-Bretonneux'},
#  {'name': 'Quatre Perray',
#   'address': '44-46 av. Gabriel-Peri 91700 Sainte-Geneviève-des-Bois'},
#  {'name': 'Cinéma de la Grange',
#   'address': "Ferme de la Tremblaye - Rue du Parc 78390 Bois-d'Arcy"},
#  {'name': 'Cinés Carné',
#   'address': 'place Marcel Carne 91240 Saint-Michel-sur-Orge'},
#  {'name': 'Salle Jacques-Brel',
#   'address': '4, rue de la Mare-aux-Carats 78180 Montigny-le-Bretonneux'},
#  {'name': 'Cinéma Atmosphère',
#   'address': 'Parc des Célestins (1 Rue Gambetta) 91460 Marcoussis'},
#  {'name': 'Pathé Conflans Sainte Honorine',
#   'address': "Rue de l'Hautil - ZA Les Boutries 78700 Conflans-Sainte-Honorine"},
#  {'name': 'Les 4 Vents',
#   'address': '80 avenue du general leclerc 77170 Brie-Comte-Robert'},
#  {'name': 'CGR Evry\nRéservation sur Allociné',
#   'address': "Centre Commercial 2 - Place de l'Agora 91000 Évry"},
#  {'name': 'La Luciole', 'address': '1, Route de Pontoise 95540 Méry-sur-Oise'},
#  {'name': 'Grenier à sel', 'address': "1, rue de l'Abreuvoir 78190 Trappes"},
#  {'name': 'Espace Philippe Noiret',
#   'address': 'Place Charles de Gaulle 78340 Les Clayes-sous-Bois'},
#  {'name': 'La Coupole',
#   'address': 'rue Jean-Francois-Millet 77380 Combs-la-Ville'},
#  {'name': 'Utopia Stella',
#   'address': "1, place Pierre-Mendes-France 95310 Saint-Ouen-l'Aumône"},
#  {'name': 'Ciné 220', 'address': 'rue Anatole-France 91220 Brétigny-sur-Orge'},
#  {'name': 'Royal Utopia',
#   'address': '14 rue Alexandre-Prachay 95300 Pontoise'},
#  {'name': 'Centre culturel',
#   'address': '96 avenue des Bruzacques 95280 Jouy-le-Moutier'},
#  {'name': 'Cinéma Agnès Varda', 'address': '1 Place Cassini 89300 Joigny'},
#  {'name': 'Cinéma Arcel',
#   'address': '15, place Léon Cassé 91100 Corbeil-Essonnes'},
#  {'name': "Cinéma de l'Ysieux",
#   'address': 'Place Jean Moulin (Sortie Gare RER D) 95470 Fosses'},
#  {'name': 'Le Conti\nRéservation sur Allociné',
#   'address': "Place du Pâtis 95290 L' Isle-Adam"},
#  {'name': 'Stars', 'address': '13, av. du General-de-Gaulle 91290 Arpajon'},
#  {'name': 'Pathé Carré Sénart',
#   'address': '3 allée du préambule, Centre Commercial Carré Sénart 77127 Lieusaint'},
#  {'name': "L'Antarès", 'address': '1 place du coeur-battant 95490 Vauréal'},
#  {'name': 'Espace Maurice-Béjart',
#   'address': '3, bd Andre-Malraux 78480 Verneuil-sur-Seine'},
#  {'name': 'Kinepolis Brétigny-sur-Orge',
#   'address': '5 rue Michèle Morgan Les Promenades de Brétigny - ZAC de la Maison Neuve 91220 Brétigny-sur-Orge'},
#  {'name': 'Ciné 7',
#   'address': 'centre commercial des Sept-Mares 78990 Élancourt'},
#  {'name': 'Studio 31\nRéservation sur Allociné',
#   'address': '31, Place d’Ariane 77700 Chessy'},
#  {'name': 'La Rotonde',
#   'address': 'place du 14-Juillet 1789 77550 Moissy-Cramayel'},
#  {'name': 'Gaumont Disney Village IMAX',
#   'address': 'Esplanade François Truffaut - Disney Village 77705 Chessy'},
#  {'name': 'Le Palace',
#   'address': '6, av. Anatole-France 95260 Beaumont-sur-Oise'},
#  {'name': 'UGC Ciné Cité Cergy',
#   'address': '8, place des trois gares 95800 Cergy-le-Haut'},
#  {'name': 'UGC Ciné Cité Cergy',
#   'address': '8, place des trois gares 95800 Cergy-le-Haut'},
#  {'name': 'Cinéma Confluences Mennecy\nRéservation sur Allociné',
#   'address': 'zac montvrain 2 91540 Mennecy'},
#  {'name': 'Megarama Chambly', 'address': '1 Place rama 60230 Chambly'},
#  {'name': 'La Barbacane', 'address': 'place du 8 Mai 1945 78650 Beynes'},
#  {'name': 'Cinéma Frédéric Dard',
#   'address': '77, rue Paul Doumer - 56, Boulevard Victor Hugo 78130 Les Mureaux'},
#  {'name': 'Cinéma Confluences Ballancourt\nRéservation sur Allociné',
#   'address': "Espace Daniel Salvi - 2, rue des Colombes - ZAC de l'Aunaie 91610 Ballancourt-sur-Essonne"},
#  {'name': 'Les 2 Scènes',
#   'address': 'Place Henri Dunant (place des fetes) 78580 Maule'},
#  {'name': 'Cinéma Paul-Grimault',
#   'address': '1, av. de la Division-Leclerc 78410 Aubergenville'},
#  {'name': "L'Elysée\nRéservation sur Allociné",
#   'address': '25 Avenue du Maréchal Joffre 60500 Chantilly'},
#  {'name': 'Espace culturel Les 26 couleurs',
#   'address': 'Rue Pasteur 77310 Saint-Fargeau-Ponthierry'}]

# %% [markdown]
# It seems like our data need some cleaning to remove parts like "Réservation sur Allociné" or "\n"

# %%
#transform our data into a pandas DataFrame
df_cinemas = pd.DataFrame(list_cinemas, columns=['name','address'])
df.shape
# Out:
# (251, 2)

# %%
#drop duplicates
df = df.drop_duplicates('address', keep='first')
df.shape
# Out:
# (245, 2)

# %%
#define a functon to clean the name of the cinema
def clean_name(string):
    while string.find('\r') != -1:
        string = string.split('\r\n')[0]
    while string.find('\n') != -1:
        string = string.split('\n')[0]
    return string

#define a function to clean the address of the cinema
def clean_address(string):
    string = ', '.join(string.split('\r\n'))
    return string

# %%
#apply our function to clean data and reset index and take a look at out data
df.name = df.name.apply(clean_name)
df.address = df.address.apply(clean_address)
df = df.reset_index(drop=True)
df
# Out:
#                                   name  \
# 0               Luminor Hôtel de Ville
# 1                  Espace Saint-Michel
# 2                       Studio Galande
# 3              Centre Georges-Pompidou
# 4                 Saint-André des Arts
# 5           MK2 Odéon (Côté St Michel)
# 6                        MK2 Beaubourg
# 7                         Christine 21
# 8      Le Champo - Espace Jacques Tati
# 9                         Nouvel Odéon
# 10                    Forum des images
# 11                           UGC Odéon
# 12                           Ecoles 21
# 13            UGC Ciné Cité Les Halles
# 14                      Reflet Medicis
# 15       Filmothèque du Quartier Latin
# 16                          UGC Danton
# 17         MK2 Odéon (Côté St Germain)
# 18                     Le Grand Action
# 19         Studio Luxembourg Accattone
# 20                    Les 3 Luxembourg
# 21                  Cinéma du Panthéon
# 22    MK2 Bastille (côté Beaumarchais)
# 23                          L'Arlequin
# 24                   Majestic Bastille
# 25                Studio des Ursulines
# 26   MK2 Bastille (côté Fg St Antoine)
# 27                        Epée de Bois
# 28             L'Archipel - PARIS CINE
# 29                        Le Grand Rex
# ..                                 ...
# 215             Espace Philippe Noiret
# 216                         La Coupole
# 217                      Utopia Stella
# 218                           Ciné 220
# 219                       Royal Utopia
# 220                    Centre culturel
# 221                 Cinéma Agnès Varda
# 222                       Cinéma Arcel
# 223                 Cinéma de l'Ysieux
# 224                           Le Conti
# 225                              Stars
# 226                 Pathé Carré Sénart
# 227                          L'Antarès
# 228              Espace Maurice-Béjart
# 229        Kinepolis Brétigny-sur-Orge
# 230                             Ciné 7
# 231                          Studio 31
# 232                         La Rotonde
# 233        Gaumont Disney Village IMAX
# 234                          Le Palace
# 235                UGC Ciné Cité Cergy
# 236         Cinéma Confluences Mennecy
# 237                   Megarama Chambly
# 238                       La Barbacane
# 239               Cinéma Frédéric Dard
# 240     Cinéma Confluences Ballancourt
# 241                       Les 2 Scènes
# 242               Cinéma Paul-Grimault
# 243                           L'Elysée
# 244    Espace culturel Les 26 couleurs
#
#                                                address
# 0      20, rue du Temple 75004 Paris 4e arrondissement
# 1    7, place Saint-Michel 75005 Paris 5e arrondiss...
# 2        42, rue Galande 75005 Paris 5e arrondissement
# 3    pl. Georges-Pompidou 75004 Paris 4e arrondisse...
# 4    30 rue Saint-André-des-Arts: caisse, salles 1 ...
# 5    7, rue Hautefeuille 75006 Paris 6e arrondissement
# 6      50, rue Rambuteau 75003 Paris 3e arrondissement
# 7       4, rue Christine 75006 Paris 6e arrondissement
# 8     51, rue des Ecoles 75005 Paris 5e arrondissement
# 9    6, rue de l'Ecole-de-Medecine 75006 Paris 6e a...
# 10   Forum des Halles, 2 rue du Cinéma 75001 Paris ...
# 11   124, bd Saint-Germain 75006 Paris 6e arrondiss...
# 12    23, rue des Ecoles 75005 Paris 5e arrondissement
# 13   7, place de la Rotonde 75001 Paris 1er arrondi...
# 14     3 rue Champollion 75005 Paris 5e arrondissement
# 15    9, rue Champollion 75005 Paris 5e arrondissement
# 16   99, bd Saint-Germain 75006 Paris 6e arrondisse...
# 17   113, bd Saint-Germain 75006 Paris 6e arrondiss...
# 18     5, rue des Ecoles 75005 Paris 5e arrondissement
# 19          20 rue Cujas 75005 Paris 5e arrondissement
# 20   67, rue Monsieur-le-Prince 75006 Paris 6e arro...
# 21   13, rue Victor-Cousin 75005 Paris 5e arrondiss...
# 22   4, boulevard Beaumarchais 75011 Paris 11e arro...
# 23      76 rue de Rennes 75006 Paris 6e arrondissement
# 24   4 boulevard Richard Lenoir 75011 Paris 11e arr...
# 25   10, rue des Ursulines 75005 Paris 5e arrondiss...
# 26   5, rue du Faubourg-Saint-Antoine 75011 Paris 1...
# 27   100, rue Mouffetard 75005 Paris 5e arrondissem...
# 28   17 bd de Strasbourg 75010 Paris 10e arrondisse...
# 29    1, bd Poissonniere 75002 Paris 2e arrondissement
# ..                                                 ...
# 215  Place Charles de Gaulle 78340 Les Clayes-sous-...
# 216      rue Jean-Francois-Millet 77380 Combs-la-Ville
# 217  1, place Pierre-Mendes-France 95310 Saint-Ouen...
# 218         rue Anatole-France 91220 Brétigny-sur-Orge
# 219            14 rue Alexandre-Prachay 95300 Pontoise
# 220     96 avenue des Bruzacques 95280 Jouy-le-Moutier
# 221                       1 Place Cassini 89300 Joigny
# 222        15, place Léon Cassé 91100 Corbeil-Essonnes
# 223  Place Jean Moulin (Sortie Gare RER D) 95470 Fo...
# 224                  Place du Pâtis 95290 L' Isle-Adam
# 225         13, av. du General-de-Gaulle 91290 Arpajon
# 226  3 allée du préambule, Centre Commercial Carré ...
# 227             1 place du coeur-battant 95490 Vauréal
# 228       3, bd Andre-Malraux 78480 Verneuil-sur-Seine
# 229  5 rue Michèle Morgan Les Promenades de Brétign...
# 230   centre commercial des Sept-Mares 78990 Élancourt
# 231                    31, Place d’Ariane 77700 Chessy
# 232     place du 14-Juillet 1789 77550 Moissy-Cramayel
# 233  Esplanade François Truffaut - Disney Village 7...
# 234      6, av. Anatole-France 95260 Beaumont-sur-Oise
# 235       8, place des trois gares 95800 Cergy-le-Haut
# 236                      zac montvrain 2 91540 Mennecy
# 237                         1 Place rama 60230 Chambly
# 238                   place du 8 Mai 1945 78650 Beynes
# 239  77, rue Paul Doumer - 56, Boulevard Victor Hug...
# 240  Espace Daniel Salvi - 2, rue des Colombes - ZA...
# 241   Place Henri Dunant (place des fetes) 78580 Maule
# 242  1, av. de la Division-Leclerc 78410 Aubergenville
# 243       25 Avenue du Maréchal Joffre 60500 Chantilly
# 244         Rue Pasteur 77310 Saint-Fargeau-Ponthierry
#
# [245 rows x 2 columns]

# %% [markdown]
# #### Next step we need to find the geographical coordinates using geopy library and the API of Bing

# %%
#set up dependencies to get geolocation
import geopy
API_KEY = '<your API key>'
geolocator = geopy.geocoders.Bing(API_KEY)

# %%
#define a function to get a latitude and longitude of the cinema
def get_lat_lon(address):
    g = None
    while g == None:
        g = geolocator.geocode(address)
    return g.latitude, g.longitude

# %%
#get geolocation of the cinemas
#if can not get a geolocation of an address, skip and give the coordinate None value
cinemas_full = []
for i in range(len(df)):
    row = df.loc[i,:]
    lat = None
    lon = None
    print("ROW", i, end=' ')
    try:
        lat,lon = get_lat_lon(row[1])
    except:
        coords = {
            'name':row[0],
            'address':row[1],
            'latitude':lat,
            'longitude': lon
        }
        cinemas_full.append(coords)
        print('Failed')
        continue
    coords = {
        'name':row[0],
        'address':row[1],
        'latitude':lat,
        'longitude': lon
    }
    cinemas_full.append(coords)
    print('Success', end=' ')
# Out:
# ROW 0 Success ROW 1 Success ROW 2 Success ROW 3 Success ROW 4 Success ROW 5 Success ROW 6 Success ROW 7 Success ROW 8 Success ROW 9 Success ROW 10 Success ROW 11 Success ROW 12 Success ROW 13 Success ROW 14 Success ROW 15 Success ROW 16 Success ROW 17 Success ROW 18 Success ROW 19 Success ROW 20 Success ROW 21 Success ROW 22 Success ROW 23 Success ROW 24 Success ROW 25 Success ROW 26 Success ROW 27 Success ROW 28 Success ROW 29 Success ROW 30 Success ROW 31 Success ROW 32 Success ROW 33 Success ROW 34 Success ROW 35 Success ROW 36 Success ROW 37 Success ROW 38 Success ROW 39 Success ROW 40 Success ROW 41 Success ROW 42 Success ROW 43 Success ROW 44 Success ROW 45 Success ROW 46 Success ROW 47 Success ROW 48 Success ROW 49 Success ROW 50 Success ROW 51 Failed
# ROW 52 Success ROW 53 Success ROW 54 Success ROW 55 Success ROW 56 Success ROW 57 Success ROW 58 Success ROW 59 Success ROW 60 Success ROW 61 Success ROW 62 Success ROW 63 Success ROW 64 Success ROW 65 Success ROW 66 Success ROW 67 Success ROW 68 Success ROW 69 Success ROW 70 Success ROW 71 Success ROW 72 Success ROW 73 Success ROW 74 Success ROW 75 Success ROW 76 Success ROW 77 Success ROW 78 Success ROW 79 Success ROW 80 Success ROW 81 Success ROW 82 Success ROW 83 Success ROW 84 Success ROW 85 Success ROW 86 Success ROW 87 Success ROW 88 Success ROW 89 Success ROW 90 Success ROW 91 Success ROW 92 Success ROW 93 Success ROW 94 Success ROW 95 Success ROW 96 Success ROW 97 Success ROW 98 Success ROW 99 Success ROW 100 Success ROW 101 Success ROW 102 Success ROW 103 Success ROW 104 Success ROW 105 Failed
# ROW 106 Success ROW 107 Success ROW 108 Success ROW 109 Success ROW 110 Success ROW 111 Success ROW 112 Success ROW 113 Success ROW 114 Success ROW 115 Success ROW 116 Success ROW 117 Success ROW 118 Success ROW 119 Success ROW 120 Success ROW 121 Success ROW 122 Success ROW 123 Success ROW 124 Success ROW 125 Success ROW 126 Success ROW 127 Success ROW 128 Success ROW 129 Success ROW 130 Success ROW 131 Success ROW 132 Success ROW 133 Success ROW 134 Success ROW 135 Success ROW 136 Success ROW 137 Success ROW 138 Success ROW 139 Success ROW 140 Success ROW 141 Success ROW 142 Success ROW 143 Success ROW 144 Success ROW 145 Success ROW 146 Success ROW 147 Failed
# ROW 148 Success ROW 149 Success ROW 150 Success ROW 151 Success ROW 152 Success ROW 153 Success ROW 154 Success ROW 155 Success ROW 156 Success ROW 157 Success ROW 158 Success ROW 159 Success ROW 160 Success ROW 161 Success ROW 162 Success ROW 163 Success ROW 164 Success ROW 165 Success ROW 166 Success ROW 167 Success ROW 168 Success ROW 169 Success ROW 170 Success ROW 171 Success ROW 172 Success ROW 173 Failed
# ROW 174 Success ROW 175 Success ROW 176 Success ROW 177 Success ROW 178 Success ROW 179 Success ROW 180 Success ROW 181 Success ROW 182 Success ROW 183 Success ROW 184 Success ROW 185 Success ROW 186 Success ROW 187 Success ROW 188 Success ROW 189 Success ROW 190 Success ROW 191 Success ROW 192 Success ROW 193 Success ROW 194 Success ROW 195 Success ROW 196 Success ROW 197 Success ROW 198 Success ROW 199 Success ROW 200 Success ROW 201 Success ROW 202 Success ROW 203 Success ROW 204 Success ROW 205 Success ROW 206 Success ROW 207 Success ROW 208 Success ROW 209 Success ROW 210 Success ROW 211 Success ROW 212 Success ROW 213 Success ROW 214 Success ROW 215 Success ROW 216 Success ROW 217 Success ROW 218 Success ROW 219 Success ROW 220 Success ROW 221 Success ROW 222 Success ROW 223 Success ROW 224 Success ROW 225 Success ROW 226 Success ROW 227 Success ROW 228 Success ROW 229 Success ROW 230 Success ROW 231 Success ROW 232 Success ROW 233 Success ROW 234 Success ROW 235 Success ROW 236 Success ROW 237 Success ROW 238 Success ROW 239 Success ROW 240 Success ROW 241 Success ROW 242 Success ROW 243 Success ROW 244 Success

# %%
#take a look at our cinema's location
cinemas_final = pd.DataFrame(cinemas_full, columns =['name','address','latitude','longitude'])
#save our data
cinemas_final.to_csv('cinemas_final.csv')

cinemas_final
# Out:
#                                   name  \
# 0               Luminor Hôtel de Ville
# 1                  Espace Saint-Michel
# 2                       Studio Galande
# 3              Centre Georges-Pompidou
# 4                 Saint-André des Arts
# 5           MK2 Odéon (Côté St Michel)
# 6                        MK2 Beaubourg
# 7                         Christine 21
# 8      Le Champo - Espace Jacques Tati
# 9                         Nouvel Odéon
# 10                    Forum des images
# 11                           UGC Odéon
# 12                           Ecoles 21
# 13            UGC Ciné Cité Les Halles
# 14                      Reflet Medicis
# 15       Filmothèque du Quartier Latin
# 16                          UGC Danton
# 17         MK2 Odéon (Côté St Germain)
# 18                     Le Grand Action
# 19         Studio Luxembourg Accattone
# 20                    Les 3 Luxembourg
# 21                  Cinéma du Panthéon
# 22    MK2 Bastille (côté Beaumarchais)
# 23                          L'Arlequin
# 24                   Majestic Bastille
# 25                Studio des Ursulines
# 26   MK2 Bastille (côté Fg St Antoine)
# 27                        Epée de Bois
# 28             L'Archipel - PARIS CINE
# 29                        Le Grand Rex
# ..                                 ...
# 215             Espace Philippe Noiret
# 216                         La Coupole
# 217                      Utopia Stella
# 218                           Ciné 220
# 219                       Royal Utopia
# 220                    Centre culturel
# 221                 Cinéma Agnès Varda
# 222                       Cinéma Arcel
# 223                 Cinéma de l'Ysieux
# 224                           Le Conti
# 225                              Stars
# 226                 Pathé Carré Sénart
# 227                          L'Antarès
# 228              Espace Maurice-Béjart
# 229        Kinepolis Brétigny-sur-Orge
# 230                             Ciné 7
# 231                          Studio 31
# 232                         La Rotonde
# 233        Gaumont Disney Village IMAX
# 234                          Le Palace
# 235                UGC Ciné Cité Cergy
# 236         Cinéma Confluences Mennecy
# 237                   Megarama Chambly
# 238                       La Barbacane
# 239               Cinéma Frédéric Dard
# 240     Cinéma Confluences Ballancourt
# 241                       Les 2 Scènes
# 242               Cinéma Paul-Grimault
# 243                           L'Elysée
# 244    Espace culturel Les 26 couleurs
#
#                                                address   latitude  longitude
# 0      20, rue du Temple 75004 Paris 4e arrondissement  48.858690   2.353590
# 1    7, place Saint-Michel 75005 Paris 5e arrondiss...  48.853090   2.344230
# 2        42, rue Galande 75005 Paris 5e arrondissement  48.851620   2.347080
# 3    pl. Georges-Pompidou 75004 Paris 4e arrondisse...  48.860680   2.351980
# 4    30 rue Saint-André-des-Arts: caisse, salles 1 ...  48.853300   2.342270
# 5    7, rue Hautefeuille 75006 Paris 6e arrondissement  48.852190   2.342790
# 6      50, rue Rambuteau 75003 Paris 3e arrondissement  48.861580   2.352290
# 7       4, rue Christine 75006 Paris 6e arrondissement  48.854460   2.340130
# 8     51, rue des Ecoles 75005 Paris 5e arrondissement  48.849980   2.343210
# 9    6, rue de l'Ecole-de-Medecine 75006 Paris 6e a...  48.850760   2.341750
# 10   Forum des Halles, 2 rue du Cinéma 75001 Paris ...  48.859140   2.347440
# 11   124, bd Saint-Germain 75006 Paris 6e arrondiss...  48.852350   2.339830
# 12    23, rue des Ecoles 75005 Paris 5e arrondissement  48.848380   2.348970
# 13   7, place de la Rotonde 75001 Paris 1er arrondi...  48.896160   2.385660
# 14     3 rue Champollion 75005 Paris 5e arrondissement  48.849800   2.343000
# 15    9, rue Champollion 75005 Paris 5e arrondissement  48.849510   2.342790
# 16   99, bd Saint-Germain 75006 Paris 6e arrondisse...  48.852140   2.339000
# 17   113, bd Saint-Germain 75006 Paris 6e arrondiss...  48.852440   2.338270
# 18     5, rue des Ecoles 75005 Paris 5e arrondissement  48.847540   2.352120
# 19          20 rue Cujas 75005 Paris 5e arrondissement  48.848150   2.341980
# 20   67, rue Monsieur-le-Prince 75006 Paris 6e arro...  48.848410   2.340770
# 21   13, rue Victor-Cousin 75005 Paris 5e arrondiss...  48.847500   2.342300
# 22   4, boulevard Beaumarchais 75011 Paris 11e arro...  48.854540   2.369050
# 23      76 rue de Rennes 75006 Paris 6e arrondissement  48.851280   2.330650
# 24   4 boulevard Richard Lenoir 75011 Paris 11e arr...  48.853990   2.369950
# 25   10, rue des Ursulines 75005 Paris 5e arrondiss...  48.842730   2.342040
# 26   5, rue du Faubourg-Saint-Antoine 75011 Paris 1...  48.853160   2.370720
# 27   100, rue Mouffetard 75005 Paris 5e arrondissem...  48.841320   2.349540
# 28   17 bd de Strasbourg 75010 Paris 10e arrondisse...  48.870460   2.354660
# 29    1, bd Poissonniere 75002 Paris 2e arrondissement  48.870550   2.347750
# ..                                                 ...        ...        ...
# 215  Place Charles de Gaulle 78340 Les Clayes-sous-...  48.821390   1.986810
# 216      rue Jean-Francois-Millet 77380 Combs-la-Ville  48.659500   2.567380
# 217  1, place Pierre-Mendes-France 95310 Saint-Ouen...  49.044600   2.107000
# 218         rue Anatole-France 91220 Brétigny-sur-Orge  48.608350   2.304570
# 219            14 rue Alexandre-Prachay 95300 Pontoise  49.049190   2.099050
# 220     96 avenue des Bruzacques 95280 Jouy-le-Moutier  49.007650   2.044760
# 221                       1 Place Cassini 89300 Joigny  47.957230   3.400080
# 222        15, place Léon Cassé 91100 Corbeil-Essonnes  48.603920   2.469090
# 223  Place Jean Moulin (Sortie Gare RER D) 95470 Fo...  49.099430   2.525100
# 224                  Place du Pâtis 95290 L' Isle-Adam  49.110180   2.211600
# 225         13, av. du General-de-Gaulle 91290 Arpajon  48.590690   2.250120
# 226  3 allée du préambule, Centre Commercial Carré ...  48.616150   2.545490
# 227             1 place du coeur-battant 95490 Vauréal  49.030120   2.021180
# 228       3, bd Andre-Malraux 78480 Verneuil-sur-Seine  48.979210   1.974610
# 229  5 rue Michèle Morgan Les Promenades de Brétign...  48.579229   2.299809
# 230   centre commercial des Sept-Mares 78990 Élancourt  48.776997   1.957012
# 231                    31, Place d’Ariane 77700 Chessy  48.856120   2.773740
# 232     place du 14-Juillet 1789 77550 Moissy-Cramayel  48.628500   2.590360
# 233  Esplanade François Truffaut - Disney Village 7...  48.869500   2.783510
# 234      6, av. Anatole-France 95260 Beaumont-sur-Oise  49.141390   2.283080
# 235       8, place des trois gares 95800 Cergy-le-Haut  42.671322  -1.812990
# 236                      zac montvrain 2 91540 Mennecy  48.565125   2.438809
# 237                         1 Place rama 60230 Chambly  49.159670   2.257370
# 238                   place du 8 Mai 1945 78650 Beynes  48.856520   1.875880
# 239  77, rue Paul Doumer - 56, Boulevard Victor Hug...  48.992530   1.911830
# 240  Espace Daniel Salvi - 2, rue des Colombes - ZA...  48.528730   2.388460
# 241   Place Henri Dunant (place des fetes) 78580 Maule  48.911810   1.850010
# 242  1, av. de la Division-Leclerc 78410 Aubergenville  48.958900   1.855230
# 243       25 Avenue du Maréchal Joffre 60500 Chantilly  49.191370   2.464220
# 244         Rue Pasteur 77310 Saint-Fargeau-Ponthierry  48.535310   2.546750
#
# [245 rows x 4 columns]

# %% [markdown]
# After taking a look at our data, we have found 245 cinemas in Paris. This doesn't seem right because after some research, there are only about 80 cinemas within Paris.
# If we pay attention to the zip code in cluded in the address, there are many zip codes that are not from Paris.

# %% [markdown]
# #### We want to find only cinemas within Paris but this list contains cinemas nearby Paris. The next step is to extract only cinemas that is within Paris

# %%
#take a look a the Null data
nan = cinemas_final[cinemas_final.latitude.isnull()]
nan
# Out:
#                           name  \
# 51            MK2 Grand Palais
# 105  Les 3 Cinés - Robespierre
# 147               Le Colombier
# 173    UGC Ciné Cité O'Parinor
#
#                                                address  latitude  longitude
# 51   A l'intérieur du Grand Palais: à l'angle du Co...       NaN        NaN
# 105  19, avenue Maximilien Robespierre 94400 Vitry-...       NaN        NaN
# 147        Place Charles de Gaulle 92410 Ville-d'Avray       NaN        NaN
# 173  Centre commercial O’Parinor Le Haut de Galy 93...       NaN        NaN

# %%
# drop the null data since they do not contain zipcode within paris
cinemas_final = cinemas_final.dropna()

# %% [markdown]
# #### Next step
# To check wether a cinema is in Paris, we will check if the postal code in the address is included in the list of 20 postal codes of districts (or arrondissements) in Paris. <br> After a quick search, we know that the postal code in Paris has the form of "750xx" with xx is from 01 to 20, which equals to 20 districts in Paris.

# %%
# Create a list of postal code in Paris
district_list = []
for i in range(1,21):
    district = '750{}'.format(str(i).zfill(2))
    district_list.append(district)
print(district_list)
# Out:
# ['75001', '75002', '75003', '75004', '75005', '75006', '75007', '75008', '75009', '75010', '75011', '75012', '75013', '75014', '75015', '75016', '75017', '75018', '75019', '75020']

# %%
# Define a function to check if the address is within Paris
def in_paris(address):
    district_list = ['75001', '75002', '75003', '75004', '75005', '75006', '75007', '75008',
                     '75009', '75010', '75011', '75012', '75013', '75014', '75015', '75016',
                     '75017', '75018', '75019', '75020']
    for district in district_list:
        if district in address:
            return True
    return False

# %%
# Apply our function and take a look at our data
cinemas_final = cinemas_final[cinemas_final.address.apply(in_paris)]
cinemas_final = cinemas_final.reset_index(drop= True)
cinemas_final
# Out:
#                                  name  \
# 0              Luminor Hôtel de Ville
# 1                 Espace Saint-Michel
# 2                      Studio Galande
# 3             Centre Georges-Pompidou
# 4                Saint-André des Arts
# 5          MK2 Odéon (Côté St Michel)
# 6                       MK2 Beaubourg
# 7                        Christine 21
# 8     Le Champo - Espace Jacques Tati
# 9                        Nouvel Odéon
# 10                   Forum des images
# 11                          UGC Odéon
# 12                          Ecoles 21
# 13           UGC Ciné Cité Les Halles
# 14                     Reflet Medicis
# 15      Filmothèque du Quartier Latin
# 16                         UGC Danton
# 17        MK2 Odéon (Côté St Germain)
# 18                    Le Grand Action
# 19        Studio Luxembourg Accattone
# 20                   Les 3 Luxembourg
# 21                 Cinéma du Panthéon
# 22   MK2 Bastille (côté Beaumarchais)
# 23                         L'Arlequin
# 24                  Majestic Bastille
# 25               Studio des Ursulines
# 26  MK2 Bastille (côté Fg St Antoine)
# 27                       Epée de Bois
# 28            L'Archipel - PARIS CINE
# 29                       Le Grand Rex
# ..                                ...
# 50             Cinéma Chaplin Denfert
# 51       Le Louxor - Palais du cinéma
# 52          La Cinémathèque française
# 53                   MK2 Bibliothèque
# 54                     Gaumont Alésia
# 55           Lieu Secret - L'Entrepôt
# 56                  MK2 Quai de Loire
# 57  Gaumont Champs-Elysées - Marignan
# 58            Le Cinéma des Cinéastes
# 59                       Pathé Wepler
# 60                   Cinéma Studio 28
# 61                  MK2 Quai de Seine
# 62                UGC Ciné Cité Bercy
# 63                    Elysées Lincoln
# 64                       MK2 Gambetta
# 65       Cinéma Chaplin Saint Lambert
# 66                      UGC Normandie
# 67                          Le Balzac
# 68                       UGC George V
# 69                   Publicis Cinémas
# 70                 Gaumont Convention
# 71                   Club de l'Etoile
# 72                          Mac-Mahon
# 73                     Majestic Passy
# 74                 Pathé Beaugrenelle
# 75                    CGR Paris Lilas
# 76             UGC Ciné Cité Paris 19
# 77                  Pathé La Villette
# 78                        UGC Maillot
# 79              Gaumont Aquaboulevard
#
#                                               address   latitude  longitude
# 0     20, rue du Temple 75004 Paris 4e arrondissement  48.858690   2.353590
# 1   7, place Saint-Michel 75005 Paris 5e arrondiss...  48.853090   2.344230
# 2       42, rue Galande 75005 Paris 5e arrondissement  48.851620   2.347080
# 3   pl. Georges-Pompidou 75004 Paris 4e arrondisse...  48.860680   2.351980
# 4   30 rue Saint-André-des-Arts: caisse, salles 1 ...  48.853300   2.342270
# 5   7, rue Hautefeuille 75006 Paris 6e arrondissement  48.852190   2.342790
# 6     50, rue Rambuteau 75003 Paris 3e arrondissement  48.861580   2.352290
# 7      4, rue Christine 75006 Paris 6e arrondissement  48.854460   2.340130
# 8    51, rue des Ecoles 75005 Paris 5e arrondissement  48.849980   2.343210
# 9   6, rue de l'Ecole-de-Medecine 75006 Paris 6e a...  48.850760   2.341750
# 10  Forum des Halles, 2 rue du Cinéma 75001 Paris ...  48.859140   2.347440
# 11  124, bd Saint-Germain 75006 Paris 6e arrondiss...  48.852350   2.339830
# 12   23, rue des Ecoles 75005 Paris 5e arrondissement  48.848380   2.348970
# 13  7, place de la Rotonde 75001 Paris 1er arrondi...  48.896160   2.385660
# 14    3 rue Champollion 75005 Paris 5e arrondissement  48.849800   2.343000
# 15   9, rue Champollion 75005 Paris 5e arrondissement  48.849510   2.342790
# 16  99, bd Saint-Germain 75006 Paris 6e arrondisse...  48.852140   2.339000
# 17  113, bd Saint-Germain 75006 Paris 6e arrondiss...  48.852440   2.338270
# 18    5, rue des Ecoles 75005 Paris 5e arrondissement  48.847540   2.352120
# 19         20 rue Cujas 75005 Paris 5e arrondissement  48.848150   2.341980
# 20  67, rue Monsieur-le-Prince 75006 Paris 6e arro...  48.848410   2.340770
# 21  13, rue Victor-Cousin 75005 Paris 5e arrondiss...  48.847500   2.342300
# 22  4, boulevard Beaumarchais 75011 Paris 11e arro...  48.854540   2.369050
# 23     76 rue de Rennes 75006 Paris 6e arrondissement  48.851280   2.330650
# 24  4 boulevard Richard Lenoir 75011 Paris 11e arr...  48.853990   2.369950
# 25  10, rue des Ursulines 75005 Paris 5e arrondiss...  48.842730   2.342040
# 26  5, rue du Faubourg-Saint-Antoine 75011 Paris 1...  48.853160   2.370720
# 27  100, rue Mouffetard 75005 Paris 5e arrondissem...  48.841320   2.349540
# 28  17 bd de Strasbourg 75010 Paris 10e arrondisse...  48.870460   2.354660
# 29   1, bd Poissonniere 75002 Paris 2e arrondissement  48.870550   2.347750
# ..                                                ...        ...        ...
# 50  24, place Denfert-Rochereau 75014 Paris 14e ar...  48.833880   2.330980
# 51  170 Boulevard de Magenta 75010 Paris 10e arron...  48.883398   2.349899
# 52     51 rue de Bercy 75012 Paris 12e arrondissement  48.843670   2.373600
# 53  128-162 avenue de France 75013 Paris 13e arron...  48.831670   2.376000
# 54  73, av. du Gal-Leclerc 75014 Paris 14e arrondi...  48.828170   2.327460
# 55  7-9, rue Francis-de-Pressense 75014 Paris 14e ...  48.833940   2.316510
# 56     7 quai de Loire 75019 Paris 19e arrondissement  48.883870   2.371600
# 57  27-33 avenue des Champs-Elysées 75008 Paris 8e...  48.869460   2.307480
# 58    7, av. de Clichy 75017 Paris 17e arrondissement  48.884300   2.326890
# 59  140, bd de Clichy et 8, av de Clichy 75018 Par...  48.883940   2.328030
# 60     10, rue Tholoze 75018 Paris 18e arrondissement  48.886140   2.335340
# 61  14, quai de la Seine 75019 Paris 19e arrondiss...  48.885070   2.371490
# 62  2, cour Saint-Emilion 75012 Paris 12e arrondis...  48.831835   2.385233
# 63      14, rue Lincoln 75008 Paris 8e arrondissement  48.870510   2.303160
# 64     6, rue Belgrand 75020 Paris 20e arrondissement  48.864760   2.399560
# 65       6, rue Peclet 75015 Paris 15e arrondissement  48.843200   2.298560
# 66  116Bis, Avenue des Champs-Elysées 75008 Paris ...  48.872270   2.300940
# 67        1, rue Balzac 75008 Paris 8e arrondissement  48.872820   2.299790
# 68  146, av. des Champs-Elysees 75008 Paris 8e arr...  48.872898   2.298274
# 69  129, av. des Champs-Elysees 75008 Paris 8e arr...  48.872670   2.297380
# 70  27, rue Alain-Chartier 75015 Paris 15e arrondi...  48.837790   2.296260
# 71       14 rue troyon 75017 Paris 17e arrondissement  48.876110   2.295350
# 72    5, av. Mac-Mahon 75017 Paris 17e arrondissement  48.875540   2.294480
# 73     18 rue de Passy 75016 Paris 16e arrondissement  48.858240   2.282300
# 74        7 rue Linois 75015 Paris 15e arrondissement  48.848900   2.282580
# 75  Place du maquis du Vercors 75020 Paris 20e arr...  48.877670   2.408910
# 76  166, boulevard Mac Donald 75019 Paris 19e arro...  48.898990   2.376760
# 77  30 avenue Corentin Cariou 75019 Paris 19e arro...  48.896990   2.385120
# 78  porte Maillot, Palais des Congres 75017 Paris ...  48.878490   2.280250
# 79  8-16, rue du Colonel-Pierre-Avia 75015 Paris 1...  48.831480   2.277520
#
# [80 rows x 4 columns]

# %% [markdown]
# Now our data only contains 80 cinemas within Paris, which is about right. Next step is to draw a map to check if our cinemas is in fact all in Paris

# %%
# This a the geolocation of Paris resulted from another search I did previously.
# I didn't include the code because it was similar to what we did in week 2 and week 3.
latitude = 48.8572082519531
longitude = 2.34143996238708

# %%
#create map of Paris using latitude and longitude
map_paris = folium.Map(location = [latitude, longitude], zoom_start = 12)

#add markers to the map
for name, add, lat, lng in zip(cinemas_final['name'],cinemas_final['address'], 
                               cinemas_final['latitude'],cinemas_final['longitude']):
    label = 'Cinema {} - {}'.format(name,add)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7
    ).add_to(map_paris)
    
map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2.  Location of top 5 popular cinemas in Paris

# %% [markdown]
# We can find the list of popular cinemas in this website http://www.allocine.fr/salle/
# #### Next step
# We will try to scrap the name and address of these popular cinemas

# %%
# get the part of the website that contains data of the 10 most popular cinemas in France
url = 'http://www.allocine.fr/salle/'
source = requests.get(url)
soup = bs(source.text, 'lxml')
table = soup.find_all('table', class_="noborder")[0]
rows = table.find_all('tr')

# %%
# Extract from the data name, address
top_cinemas = []
for row in rows:
    row = row.text.strip().split('\n')
    name = row[-2]
    address = row[-1]
    
    # Only get the geolocation from popular cinemas in Paris
    if in_paris(address):
        lat,lon = get_lat_lon(address)
        popular_cine = {
            'name':name,
            'address':address,
            'latitude':lat,
            'longitude':lon
        }
        top_cinemas.append(popular_cine)
    # print out cinemas that are note in paris to double check
    else: 
        print(address, "NOT IN PARIS")
        continue
# Out:
# Le Dôme - Centre commercial Les 4 Temps 92092 Paris - La Défense NOT IN PARIS
# chemin des Pennes aux Pins 13170 Les Pennes-Mirabeau NOT IN PARIS
# 1 avenue de la Source de la Bievre 78180 Montigny-le-Bretonneux NOT IN PARIS
# Centre commercial Belle-Epine 94320 Thiais NOT IN PARIS
# 3 allée du préambule, Centre Commercial Carré Sénart 77127 Lieusaint NOT IN PARIS

# %%
#take a look at our data
df_top_cinemas = pd.DataFrame(top_cinemas, columns=['name','address','latitude','longitude'])
df_top_cinemas.to_csv('top_cinemas_in_paris.csv')
df_top_cinemas
# Out:
#                        name  \
# 0  UGC Ciné Cité Les Halles
# 1       UGC Ciné Cité Bercy
# 2          MK2 Bibliothèque
# 3              Pathé Wepler
# 4        Pathé Beaugrenelle
#
#                                              address   latitude  longitude
# 0  7, place de la Rotonde 75001 Paris 1er arrondi...  48.896160   2.385660
# 1  2, cour Saint-Emilion 75012 Paris 12e arrondis...  48.831835   2.385233
# 2  128-162 avenue de France 75013 Paris 13e arron...  48.831670   2.376000
# 3  140, bd de Clichy et 8, av de Clichy 75018 Par...  48.883940   2.328030
# 4        7 rue Linois 75015 Paris 15e arrondissement  48.848900   2.282580

# %% [markdown]
# #### Mapping the popular with cinemas with all other cinemas

# %%
#create map of Toronto using latitude and longitude
map_paris2 = folium.Map(location = [latitude, longitude], zoom_start = 12)

#add markers of all cinemas in Paris to the map
for name, add, lat, lng in zip(cinemas_final['name'],cinemas_final['address'], 
                               cinemas_final['latitude'],cinemas_final['longitude']):
    label = 'Cinema {} - {}'.format(name,add)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7
    ).add_to(map_paris2)
#add markers of 5 top cinemas in Paris to the map
for name, add, lat, lng in zip(df_top_cinemas['name'],df_top_cinemas['address'], 
                               df_top_cinemas['latitude'],df_top_cinemas['longitude']):
    label = 'Cinema {} - {}'.format(name,add)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup = label,
        color = 'red',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7
    ).add_to(map_paris2)
    
    
map_paris2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3. Geographic coordinates of 5 possible cinema addresses
# I will choose randomly 5 addresses out of all cinemas in Paris (except the top 5 popular ones) and pretend that those 5 address don't have cinema.
# Those 5 randomly choosen addresses will be possible locations to evaluate.

# %% [markdown]
# ### 4. Eating, Shopping and Public transportation facility around cinema
# The recommended cinema location needs to have many eating and shopping venues nearby. Convenient public transport is also required.
# I can use FourSquare API to find these venues around the location.
#
# 5 minutes walking distance is about 500m. I think it is the suitable distance to search nearby venues.

# %% [markdown]
# Following categories will be used for finding the target venues. Full list of categories: https://developer.foursquare.com/docs/resources/categories

# %%
print('Use the first cinema "{}" in the list as example to explore venues nearyby'.format(cinemas_final['name'][0]))
# Out:
# Use the first cinema "Luminor Hôtel de Ville" in the list as example to explore venues nearyby

# %%
fs_categories = {
    'Food': '4d4b7105d754a06374d81259',
    'Shop & Service': '4d4b7105d754a06378d81259',
    'Bus Stop': '52f2ab2ebcbc57f1066b8b4f',
    'Metro Station': '4bf58dd8d48988d1fd931735',
    'Nightlife Spot': '4d4b7105d754a06376d81259',
    'Arts & Entertainment': '4d4b7104d754a06370d81259'
}

# %%
', '.join([ cat for cat in fs_categories])
# Out:
# 'Food, Shop & Service, Bus Stop, Metro Station, Nightlife Spot, Arts & Entertainment'

# %%
cinema = cinemas_final.loc[0]

# %%
from six.moves.urllib import parse
from pandas.io.json import json_normalize

# %%
CLIENT_ID = '<Your_foursquare_client_id>'
CLIENT_SECRET = '<Your_foursquare_secret_key>'
VERSION = '20181104'
LATITUDE,LONGITUDE = cinema['latitude'],cinema['longitude']
RADIUS = 500

# %%
http = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}'

# %%
url = http.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    LATITUDE,
    LONGITUDE,
    RADIUS,
    CATID
)

# %%
resp = requests.get(url).json()
resp['response']['venues']
# Out:
# [{'id': '4b2e4a89f964a520fcdd24e3',
#   'name': 'Les Marronniers',
#   'location': {'address': '18 rue des Archives',
#    'lat': 48.85783014865521,
#    'lng': 2.354572839448655,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85783014865521,
#      'lng': 2.354572839448655}],
#    'distance': 119,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['18 rue des Archives', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '5293ae7d11d2fba382d9f652',
#   'name': 'Benedict',
#   'location': {'address': '19 rue Sainte-Croix-de-la-Bretonnerie',
#    'lat': 48.85820815365001,
#    'lng': 2.3560811411196494,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85820815365001,
#      'lng': 2.3560811411196494}],
#    'distance': 190,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['19 rue Sainte-Croix-de-la-Bretonnerie',
#     '75004 Paris',
#     'France']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4bbb21a91261d13aa847eb98',
#   'name': 'La Caféothèque de Paris',
#   'location': {'address': "52 rue de l'Hôtel de Ville",
#    'lat': 48.85419716409349,
#    'lng': 2.355713729818569,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85419716409349,
#      'lng': 2.355713729818569}],
#    'distance': 523,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ["52 rue de l'Hôtel de Ville",
#     '75004 Paris',
#     'France']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b754d15f964a52026052ee3',
#   'name': 'KFC',
#   'location': {'address': '31-35 boulevard de Sébastopol',
#    'crossStreet': 'Rue Berger',
#    'lat': 48.860739717750015,
#    'lng': 2.3490629530848577,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.860739717750015,
#      'lng': 2.3490629530848577}],
#    'distance': 402,
#    'postalCode': '75001',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['31-35 boulevard de Sébastopol (Rue Berger)',
#     '75001 Paris',
#     'France']},
#   'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#     'name': 'Fried Chicken Joint',
#     'pluralName': 'Fried Chicken Joints',
#     'shortName': 'Fried Chicken',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4ac0ca73f964a5208c9420e3',
#   'name': "McDonald's",
#   'location': {'address': '5 rue du Renard',
#    'lat': 48.857928179963686,
#    'lng': 2.351476550102234,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.857928179963686,
#      'lng': 2.351476550102234}],
#    'distance': 176,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['5 rue du Renard', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d16e941735',
#     'name': 'Fast Food Restaurant',
#     'pluralName': 'Fast Food Restaurants',
#     'shortName': 'Fast Food',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '566c328f498e2eba79c3d80a',
#   'name': 'Terres de Café',
#   'location': {'address': '40 rue des Blancs-Manteaux',
#    'lat': 48.859762823640466,
#    'lng': 2.354948434170109,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.859762823640466,
#      'lng': 2.354948434170109}],
#    'distance': 155,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'neighborhood': 'Marais, Paris',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['40 rue des Blancs-Manteaux',
#     '75004 Paris',
#     'France']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b6b40daf964a52052fc2be3',
#   'name': 'Georges',
#   'location': {'address': 'Place Georges Pompidou',
#    'lat': 48.860017542928325,
#    'lng': 2.3520585894584656,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.860017542928325,
#      'lng': 2.3520585894584656}],
#    'distance': 185,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['Place Georges Pompidou', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '49303727'},
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b867a97f964a520e48b31e3',
#   'name': "L'As du Fallafel",
#   'location': {'address': '34 rue des Rosiers',
#    'crossStreet': 'Rue des Ecouffes',
#    'lat': 48.857381354315706,
#    'lng': 2.359014657852358,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.857381354315706,
#      'lng': 2.359014657852358}],
#    'distance': 423,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['34 rue des Rosiers (Rue des Ecouffes)',
#     '75004 Paris',
#     'France']},
#   'categories': [{'id': '4bf58dd8d48988d10b941735',
#     'name': 'Falafel Restaurant',
#     'pluralName': 'Falafel Restaurants',
#     'shortName': 'Falafel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b3b61b2f964a5201e7325e3',
#   'name': 'Les Philosophes',
#   'location': {'address': '28 rue Vieille du Temple',
#    'lat': 48.857296,
#    'lng': 2.357524,
#    'labeledLatLngs': [{'label': 'display', 'lat': 48.857296, 'lng': 2.357524}],
#    'distance': 327,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['28 rue Vieille du Temple', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '5933d8c0f2905e16619d0adf',
#   'name': 'La Mouette Rieuse',
#   'location': {'address': 'Rue Pavé',
#    'lat': 48.85670853893964,
#    'lng': 2.361315623158024,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85670853893964,
#      'lng': 2.361315623158024}],
#    'distance': 607,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['Rue Pavé', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d114951735',
#     'name': 'Bookstore',
#     'pluralName': 'Bookstores',
#     'shortName': 'Bookstore',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '526d201d11d2d42b81af4ee6',
#   'name': 'Miznon',
#   'location': {'address': '22 rue des Ecouffes',
#    'lat': 48.857200621424404,
#    'lng': 2.3589573284780676,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.857200621424404,
#      'lng': 2.3589573284780676}],
#    'distance': 426,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['22 rue des Ecouffes', '75004 Paris', 'France']},
#   'categories': [{'id': '56aa371be4b08b9a8d573529',
#     'name': 'Israeli Restaurant',
#     'pluralName': 'Israeli Restaurants',
#     'shortName': 'Israeli',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4cc9d3255c17b60c53820b05',
#   'name': 'La Droguerie du Marais',
#   'location': {'address': '56 rue des Rosiers',
#    'lat': 48.857837832158246,
#    'lng': 2.3580553473763914,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.857837832158246,
#      'lng': 2.3580553473763914}],
#    'distance': 340,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['56 rue des Rosiers', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4af77f16f964a520970922e3',
#   'name': 'La Perle',
#   'location': {'address': '78 rue Vieille du Temple',
#    'lat': 48.85999024285714,
#    'lng': 2.360895,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85999024285714,
#      'lng': 2.360895}],
#    'distance': 554,
#    'postalCode': '75003',
#    'cc': 'FR',
#    'neighborhood': 'Marais',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['78 rue Vieille du Temple', '75003 Paris', 'France']},
#   'categories': [{'id': '52e81612bcbc57f1066b79f1',
#     'name': 'Bistro',
#     'pluralName': 'Bistros',
#     'shortName': 'Bistro',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4bddacc9e75c0f473624c503',
#   'name': 'Le Voltigeur',
#   'location': {'address': '45 rue des Francs Bourgeois',
#    'lat': 48.85830144137269,
#    'lng': 2.3592711230898002,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85830144137269,
#      'lng': 2.3592711230898002}],
#    'distance': 418,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['45 rue des Francs Bourgeois',
#     '75004 Paris',
#     'France']},
#   'categories': [{'id': '52e81612bcbc57f1066b79f1',
#     'name': 'Bistro',
#     'pluralName': 'Bistros',
#     'shortName': 'Bistro',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b73c62cf964a52073bb2de3',
#   'name': 'Starbucks Coffee',
#   'location': {'address': '11 boulevard Sébastopol',
#    'lat': 48.85890228571129,
#    'lng': 2.3481506109237666,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85890228571129,
#      'lng': 2.3481506109237666}],
#    'distance': 399,
#    'postalCode': '75001',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['11 boulevard Sébastopol', '75001 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4d9da49ec97a236afb68c199',
#   'name': 'Starbucks Coffee',
#   'location': {'address': '46 rue de Rivoli',
#    'lat': 48.85674236923096,
#    'lng': 2.354907012089519,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85674236923096,
#      'lng': 2.354907012089519}],
#    'distance': 237,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['46 rue de Rivoli', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4adcda04f964a520373221e3',
#   'name': 'Mariage Frères',
#   'location': {'address': '30 rue du Bourg-Tibourg',
#    'lat': 48.85776928296051,
#    'lng': 2.356618019905924,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85776928296051,
#      'lng': 2.356618019905924}],
#    'distance': 244,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['30 rue du Bourg-Tibourg', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d1dc931735',
#     'name': 'Tea Room',
#     'pluralName': 'Tea Rooms',
#     'shortName': 'Tea Room',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b9ea1f5f964a5206cf536e3',
#   'name': 'Café Benjamin',
#   'location': {'address': '53 rue de Rivoli',
#    'lat': 48.859052621593776,
#    'lng': 2.3464001481921746,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.859052621593776,
#      'lng': 2.3464001481921746}],
#    'distance': 528,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['53 rue de Rivoli', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d116941735',
#     'name': 'Bar',
#     'pluralName': 'Bars',
#     'shortName': 'Bar',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b700b25f964a5209d042de3',
#   'name': 'Le Roi de Pique',
#   'location': {'address': '126 rue du Temple',
#    'lat': 48.86337459584866,
#    'lng': 2.3582987922392618,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.86337459584866,
#      'lng': 2.3582987922392618}],
#    'distance': 625,
#    'postalCode': '75003',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['126 rue du Temple', '75003 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4adcda08f964a520803321e3',
#   'name': 'Café Rive Droite',
#   'location': {'address': '2 rue Berger',
#    'lat': 48.86084691113991,
#    'lng': 2.3488372564315796,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.86084691113991,
#      'lng': 2.3488372564315796}],
#    'distance': 422,
#    'postalCode': '75001',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['2 rue Berger', '75001 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d120941735',
#     'name': 'Karaoke Bar',
#     'pluralName': 'Karaoke Bars',
#     'shortName': 'Karaoke',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b263913f964a520527924e3',
#   'name': 'Starbucks Coffee',
#   'location': {'address': '4 rue Aubry Le Boucher',
#    'lat': 48.86024070312239,
#    'lng': 2.350421785021407,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.86024070312239,
#      'lng': 2.350421785021407}],
#    'distance': 289,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['4 rue Aubry Le Boucher', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4c28dd493492a593d206b828',
#   'name': "McDonald's",
#   'location': {'address': '12 rue Berger',
#    'lat': 48.86087580698255,
#    'lng': 2.3481683899417445,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.86087580698255,
#      'lng': 2.3481683899417445}],
#    'distance': 465,
#    'postalCode': '75001',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['12 rue Berger', '75001 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d16e941735',
#     'name': 'Fast Food Restaurant',
#     'pluralName': 'Fast Food Restaurants',
#     'shortName': 'Fast Food',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b657b5bf964a520fbf12ae3',
#   'name': 'Le Loir dans la Théière',
#   'location': {'address': '3 rue des Rosiers',
#    'lat': 48.85634089988964,
#    'lng': 2.3610769355582812,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85634089988964,
#      'lng': 2.3610769355582812}],
#    'distance': 607,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['3 rue des Rosiers', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d1dc931735',
#     'name': 'Tea Room',
#     'pluralName': 'Tea Rooms',
#     'shortName': 'Tea Room',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b0e7b3df964a520dd5723e3',
#   'name': 'Robert et Louise',
#   'location': {'address': '64 rue Vieille du Temple',
#    'lat': 48.85914311778442,
#    'lng': 2.3594878529269567,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85914311778442,
#      'lng': 2.3594878529269567}],
#    'distance': 434,
#    'postalCode': '75003',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['64 rue Vieille du Temple', '75003 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d1cc941735',
#     'name': 'Steakhouse',
#     'pluralName': 'Steakhouses',
#     'shortName': 'Steakhouse',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4d690722b6f46dcbe2391cb2',
#   'name': 'Le Palais des Thés',
#   'location': {'address': '64 rue Vieille du Temple',
#    'lat': 48.858922841346036,
#    'lng': 2.359178181942205,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.858922841346036,
#      'lng': 2.359178181942205}],
#    'distance': 410,
#    'postalCode': '75003',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['64 rue Vieille du Temple', '75003 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d1f5941735',
#     'name': 'Gourmet Shop',
#     'pluralName': 'Gourmet Shops',
#     'shortName': 'Gourmet',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b1281eff964a520628a23e3',
#   'name': 'King Falafel Palace',
#   'location': {'address': '26 rue des Rosiers',
#    'lat': 48.85714188941629,
#    'lng': 2.3594797352362833,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.85714188941629,
#      'lng': 2.3594797352362833}],
#    'distance': 464,
#    'postalCode': '75004',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['26 rue des Rosiers', '75004 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d10b941735',
#     'name': 'Falafel Restaurant',
#     'pluralName': 'Falafel Restaurants',
#     'shortName': 'Falafel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b5ed554f964a520529a29e3',
#   'name': 'La Terrasse des Archives',
#   'location': {'address': '51 rue des Archives',
#    'lat': 48.86129717812386,
#    'lng': 2.3580024792708985,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.86129717812386,
#      'lng': 2.3580024792708985}],
#    'distance': 434,
#    'postalCode': '75003',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['51 rue des Archives', '75003 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4e552b70ae60e3d6b7f6ea7a',
#   'name': 'Starbucks Coffee',
#   'location': {'address': '77 rue Rambuteau',
#    'crossStreet': 'Rue Saint-Denis',
#    'lat': 48.86212515693982,
#    'lng': 2.3495961648616857,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.86212515693982,
#      'lng': 2.3495961648616857}],
#    'distance': 481,
#    'postalCode': '75001',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['77 rue Rambuteau (Rue Saint-Denis)',
#     '75001 Paris',
#     'France']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '4b2745cdf964a520928524e3',
#   'name': 'Le Zimmer',
#   'location': {'address': '1 place du Châtelet',
#    'lat': 48.857869228959245,
#    'lng': 2.34698735671843,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.857869228959245,
#      'lng': 2.34698735671843}],
#    'distance': 492,
#    'postalCode': '75001',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['1 place du Châtelet', '75001 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1542542513',
#   'hasPerk': False},
#  {'id': '560d03b5498eaea729b6bf10',
#   'name': 'Trois Fois plus de Piment',
#   'location': {'address': 'Rue Saint-Martin 184',
#    'crossStreet': 'Rue aux Ours',
#    'lat': 48.8628,
#    'lng': 2.35237,
#    'labeledLatLngs': [{'label': 'display', 'lat': 48.8628, 'lng': 2.35237}],
#    'distance': 466,
#    'postalCode': '75003',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['Rue Saint-Martin 184 (Rue aux Ours)',
#     '75003 Paris',
#     'France']},
#   'categories': [{'id': '52af3b773cf9994f4e043c03',
#     'name': 'Szechuan Restaurant',
#     'pluralName': 'Szechuan Restaurants',
#     'shortName': 'Szechuan',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '194002375'},
#   'referralId': 'v-1542542513',
#   'hasPerk': False}]

# %%
df__ = json_normalize(resp['response']['venues'])

# %%
df__.columns
# Out:
# Index(['categories', 'hasPerk', 'id', 'location.address', 'location.cc',
#        'location.city', 'location.country', 'location.crossStreet',
#        'location.distance', 'location.formattedAddress',
#        'location.labeledLatLngs', 'location.lat', 'location.lng',
#        'location.neighborhood', 'location.postalCode', 'location.state',
#        'name', 'referralId', 'venuePage.id'],
#       dtype='object')

# %%
# Define a function to search nearby information and convert the result as dataframe
def venues_nearby(latitude, longitude, category, verbose=True):    
    url = http.format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        latitude,
        longitude,
        RADIUS,
        fs_categories[category]
    )
    results = requests.get(url).json()['response']
    df = json_normalize(results['venues'])
    cols = ['name','latitude','longitude']    
    if( len(df) == 0 ):        
        df = pd.DataFrame(columns=cols)
    else:        
        df = df[['name','location.lat','location.lng']]
        df.columns = cols
    if( verbose ):
        print('{} "{}" venues are found within {}m of location'.format(len(df), category, RADIUS))
    return df

# %% [markdown]
# #### Find Metro Station around the cinema

# %%
venues_nearby(cinema['latitude'], cinema['longitude'], 'Metro Station').head()
# Out:
# 4 "Metro Station" venues are found within 500m of location
#                            name   latitude  longitude
# 0   Métro Hôtel de Ville [1,11]  48.857353   2.351761
# 1  Métro Châtelet [1,4,7,11,14]  48.859099   2.346813
# 2          Métro Pont Marie [7]  48.853872   2.356778
# 3          Métro Rambuteau [11]  48.861298   2.353106

# %% [markdown]
# #### Find Bus Stop around the cinema

# %%
venues_nearby(cinema['latitude'], cinema['longitude'], 'Bus Stop').head()
# Out:
# 15 "Bus Stop" venues are found within 500m of location
#                                                 name   latitude  longitude
# 0                       Arrêt Hôtel de Ville [72,74]  48.856880   2.350751
# 1                    Arrêt Archives-Haudriettes (29)  48.861180   2.358411
# 2                             Arrêt La Verrerie [75]  48.857859   2.354724
# 3                 Arrêt Hôtel de Ville [67,69,76,96]  48.857162   2.352920
# 4  Arrêt Centre Georges Pompidou [38,47,75,N12,N1...  48.860359   2.352556

# %% [markdown]
# #### Find eating places around the cinema

# %%
venues_nearby(cinema['latitude'], cinema['longitude'], 'Food').head()
# Out:
# 30 "Food" venues are found within 500m of location
#                       name   latitude  longitude
# 0          Les Marronniers  48.857830   2.354573
# 1                 Benedict  48.858208   2.356081
# 2  La Caféothèque de Paris  48.854197   2.355714
# 3                      KFC  48.860740   2.349063
# 4               McDonald's  48.857928   2.351477

# %% [markdown]
# #### Find arts and entertainment places around the cinema

# %%
venues_nearby(cinema['latitude'], cinema['longitude'], 'Arts & Entertainment').head()
# Out:
# 30 "Arts & Entertainment" venues are found within 500m of location
#                                              name   latitude  longitude
# 0                          Luminor Hôtel de Ville  48.858654   2.353498
# 1  Centre Pompidou – Musée National d'Art Moderne  48.860445   2.352490
# 2                              Tour Saint-Jacques  48.858031   2.348875
# 3                                       Le Renard  48.858204   2.351839
# 4                         Lafayette Anticipations  48.859167   2.354866

# %% [markdown]
# With above data, I can build a **content-based recommender systems** to resolve the problem.
#
# Combine with FourSquare API on counting how many different venues (Food, Transport, Night Life) and Paris cinema list, a **cinema nearby venues matrix** can be built. The 5 popular cinema in Paris is the **profile** to combine with cinema nearby venues matrix to become a **weighted matrix of favorite cinema**.
#
# The weighted matrix can be applied on **5 possible locations with venues information** to generate a ranking result. The **the top one** on the ranking list can be recommended to my friend.

# %% [markdown]
# ## Section 3. Methodology

# %% [markdown]
# Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, and what machine learnings were used and why.

# %% [markdown]
# TBD

# %% [markdown]
# ## Section 4. Results

# %% [markdown]
# Results section where you discuss the results.

# %% [markdown]
# TBD

# %% [markdown]
# ## Section 5. Discussion

# %% [markdown]
# Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.TBC

# %% [markdown]
# TBD

# %% [markdown]
# ## Section 6.Conclusion

# %% [markdown]
# Conclusion section where you conclude the report.

# %% [markdown]
# TBD
