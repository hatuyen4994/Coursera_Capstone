# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ## Section 1: Introduction/Business Problem

# %% [markdown]
# Introduction where you discuss the business problem and who would be interested in this project.

# %% [markdown]
# #### A friend of mine wants to open a cinema in Paris.
# He thinks that the first important thing about opening a cinema is its location and the surrounding neighborhood. He asked me to find some possible locations to open a cinema in Paris and wants me to concentrate on the selection of cinema location instead of cinema facility and rental price.
#
# He explained that in customer point of view, watching movie is a part of whole afternoon or night activities. Cinema should has **many restaurants and shopping places nearby**. Transportation is also an important factor. Customer can walk to cinema within **3 minutes** from **public transport facilities** such as bus stop and metro station.
#
# I first need to select **5 possible locations** to build the cinema. Then I will find out which location should be suggested to my friend.

# %% [markdown]
# ## Section 2: Data

# %% [markdown]
# Data where you describe the data that will be used to solve the problem and the source of the data.

# %% [markdown]
# According to the question, I need to find following data to resolve the problem.

# %% [markdown]
# ### 1. Geographic coordinate of Paris cinemas
#
# I need to **compare 5 possible locations with current cinemas** in Paris. Therefore, I need to find a list of Paris cinema and cinemas' geographic coordinates. I will scrape the data from this website and come up with a list of cinemas in Paris http://www.allocine.fr/salle/cinemas-pres-de-115755/.

# %%
#Import neccesary libraries
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import folium

# %%
#define a function to extract the name and address of the cinemas on the website
#this function will scrape the web for meta data and extract the name and address of all the cinemas include in an url
def get_cinemas(soup):
    cinemas = soup.find_all('div', class_='theaterblock j_entity_container')
    list_cinemas = []
    for i,cinema in enumerate(cinemas):
        name = cinemas[i].h2.text.strip()
        address = cinemas[i].p.text.strip()
        list_cinemas.append({
            'name':name,
            'address':address
        })
    return list_cinemas

# %%
#run the function to scraping the data from the website
endpoint = 'http://www.allocine.fr/salle/cinemas-pres-de-115755/?page={}'
list_cinemas = []
for page in range(1,33): #the information about paris cinemas is included in 32 page the website
    url = endpoint.format(str(page))
    print(url)
    source = requests.get(url)
    soup = bs(source.text, 'lxml')
    list_cinemas += get_cinemas(soup)
    print('Page', page)
# Out:
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=1
# Page 1
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=2
# Page 2
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=3
# Page 3
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=4
# Page 4
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=5
# Page 5
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=6
# Page 6
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=7
# Page 7
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=8
# Page 8
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=9
# Page 9
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=10
# Page 10
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=11
# Page 11
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=12
# Page 12
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=13
# Page 13
# http://www.allocine.fr/salle/cinemas-pres-de-115755/?page=14
# ...

# %%
# take a look at the result
list_cinemas
# Out:
# [{'name': 'Luminor Hôtel de Ville\nRéservation sur Allociné',
#   'address': '20, rue du Temple 75004 Paris 4e arrondissement'},
#  {'name': 'Espace Saint-Michel',
#   'address': '7, place Saint-Michel 75005 Paris 5e arrondissement'},
#  {'name': 'Studio Galande',
#   'address': '42, rue Galande 75005 Paris 5e arrondissement'},
#  {'name': 'Centre Georges-Pompidou',
#   'address': 'pl. Georges-Pompidou 75004 Paris 4e arrondissement\nMétro Hotel-de-Ville, Rambuteau.'},
#  {'name': 'Saint-André des Arts',
#   'address': '30 rue Saint-André-des-Arts: caisse, salles 1 & 2 - 12 rue Gît-le-Cœur, Salle 3 75006 Paris 6e arrondissement'},
#  {'name': 'MK2 Odéon (Côté St Michel)',
#   'address': '7, rue Hautefeuille 75006 Paris 6e arrondissement'},
#  {'name': 'MK2 Beaubourg',
#   'address': '50, rue Rambuteau 75003 Paris 3e arrondissement'},
#  {'name': 'Christine 21',
#   'address': '4, rue Christine 75006 Paris 6e arrondissement'},
#  {'name': 'Le Champo - Espace Jacques Tati',
# ...

# %% [markdown]
# It seems like our data need some cleaning to remove parts like "Réservation sur Allociné" or "\n"

# %%
#transform our data into a pandas DataFrame
df_cinemas = pd.DataFrame(list_cinemas, columns=['name','address'])
df.shape
# Out:
# (251, 2)

# %%
#drop duplicates
df = df.drop_duplicates('address', keep='first')
df.shape
# Out:
# (245, 2)

# %%
#define a functon to clean the name of the cinema
def clean_name(string):
    while string.find('\r') != -1:
        string = string.split('\r\n')[0]
    while string.find('\n') != -1:
        string = string.split('\n')[0]
    return string

#define a function to clean the address of the cinema
def clean_address(string):
    string = ', '.join(string.split('\r\n'))
    return string

# %%
#apply our function to clean data and reset index and take a look at out data
df.name = df.name.apply(clean_name)
df.address = df.address.apply(clean_address)
df = df.reset_index(drop=True)
df
# Out:
#                                   name  \
# 0               Luminor Hôtel de Ville
# 1                  Espace Saint-Michel
# 2                       Studio Galande
# 3              Centre Georges-Pompidou
# 4                 Saint-André des Arts
# 5           MK2 Odéon (Côté St Michel)
# 6                        MK2 Beaubourg
# 7                         Christine 21
# 8      Le Champo - Espace Jacques Tati
# 9                         Nouvel Odéon
# 10                    Forum des images
# 11                           UGC Odéon
# 12                           Ecoles 21
# 13            UGC Ciné Cité Les Halles
# 14                      Reflet Medicis
# 15       Filmothèque du Quartier Latin
# 16                          UGC Danton
# 17         MK2 Odéon (Côté St Germain)
# 18                     Le Grand Action
# 19         Studio Luxembourg Accattone
# 20                    Les 3 Luxembourg
# 21                  Cinéma du Panthéon
# 22    MK2 Bastille (côté Beaumarchais)
# ...

# %% [markdown]
# #### Next step we need to find the geographical coordinates using geopy library and the API of Bing

# %%
#set up dependencies to get geolocation
import geopy
API_KEY = 'AiZf_9fXLEk0tqCEesLzvkP2958xJmVjEcrHEmKadksvT9mGejD9nad-r3QxEYqK'
geolocator = geopy.geocoders.Bing(API_KEY)

# %%
#define a function to get a latitude and longitude of the cinema
def get_lat_lon(address):
    g = None
    while g == None:
        g = geolocator.geocode(address)
    return g.latitude, g.longitude

# %%
#get geolocation of the cinemas
#if can not get a geolocation of an address, skip and give the coordinate None value
cinemas_full = []
for i in range(len(df)):
    row = df.loc[i,:]
    lat = None
    lon = None
    print("ROW", i, end=' ')
    try:
        lat,lon = get_lat_lon(row[1])
    except:
        coords = {
            'name':row[0],
            'address':row[1],
            'latitude':lat,
            'longitude': lon
        }
        cinemas_full.append(coords)
        print('Failed')
        continue
    coords = {
        'name':row[0],
        'address':row[1],
        'latitude':lat,
        'longitude': lon
    }
    cinemas_full.append(coords)
    print('Success', end=' ')
# Out:
# ROW 0 Success ROW 1 Success ROW 2 Success ROW 3 Success ROW 4 Success ROW 5 Success ROW 6 Success ROW 7 Success ROW 8 Success ROW 9 Success ROW 10 Success ROW 11 Success ROW 12 Success ROW 13 Success ROW 14 Success ROW 15 Success ROW 16 Success ROW 17 Success ROW 18 Success ROW 19 Success ROW 20 Success ROW 21 Success ROW 22 Success ROW 23 Success ROW 24 Success ROW 25 Success ROW 26 Success ROW 27 Success ROW 28 Success ROW 29 Success ROW 30 Success ROW 31 Success ROW 32 Success ROW 33 Success ROW 34 Success ROW 35 Success ROW 36 Success ROW 37 Success ROW 38 Success ROW 39 Success ROW 40 Success ROW 41 Success ROW 42 Success ROW 43 Success ROW 44 Success ROW 45 Success ROW 46 Success ROW 47 Success ROW 48 Success ROW 49 Success ROW 50 Success ROW 51 Failed
# ...

# %%
#take a look at our cinema's location
cinemas_final = pd.DataFrame(cinemas_full, columns =['name','address','latitude','longitude'])
cinemas_final.to_csv('cinemas_final.csv')
cinemas_final
# Out:
#                                   name  \
# 0               Luminor Hôtel de Ville
# 1                  Espace Saint-Michel
# 2                       Studio Galande
# 3              Centre Georges-Pompidou
# 4                 Saint-André des Arts
# 5           MK2 Odéon (Côté St Michel)
# 6                        MK2 Beaubourg
# 7                         Christine 21
# 8      Le Champo - Espace Jacques Tati
# 9                         Nouvel Odéon
# 10                    Forum des images
# 11                           UGC Odéon
# 12                           Ecoles 21
# 13            UGC Ciné Cité Les Halles
# 14                      Reflet Medicis
# 15       Filmothèque du Quartier Latin
# 16                          UGC Danton
# 17         MK2 Odéon (Côté St Germain)
# 18                     Le Grand Action
# 19         Studio Luxembourg Accattone
# 20                    Les 3 Luxembourg
# 21                  Cinéma du Panthéon
# 22    MK2 Bastille (côté Beaumarchais)
# ...

# %% [markdown]
# After taking a look at our data, we have found 245 cinemas in Paris. This doesn't seem right because after some research, there are only about 80 cinemas within Paris.
# If we pay attention to the zip code in cluded in the address, there are many zip codes that are not from Paris.

# %% [markdown]
# #### We want to find only cinemas within Paris but this list contains cinemas nearby Paris. The next step is to extract only cinemas that is within Paris

# %%
#take a look a the Null data
nan = cinemas_final[cinemas_final.latitude.isnull()]
nan
# Out:
#                           name  \
# 51            MK2 Grand Palais
# 105  Les 3 Cinés - Robespierre
# 147               Le Colombier
# 173    UGC Ciné Cité O'Parinor
#
#                                                address  latitude  longitude
# 51   A l'intérieur du Grand Palais: à l'angle du Co...       NaN        NaN
# 105  19, avenue Maximilien Robespierre 94400 Vitry-...       NaN        NaN
# 147        Place Charles de Gaulle 92410 Ville-d'Avray       NaN        NaN
# 173  Centre commercial O’Parinor Le Haut de Galy 93...       NaN        NaN

# %%
# drop the null data since they do not contain zipcode within paris
cinemas_final = cinemas_final.dropna()

# %% [markdown]
# #### Next step
# To check wether a cinema is in Paris, we will check if the postal code in the address is included in the list of 20 postal codes of districts (or arrondissements) in Paris. <br> After a quick search, we know that the postal code in Paris has the form of "750xx" with xx is from 01 to 20, which equals to 20 districts in Paris.

# %%
# Create a list of postal code in Paris
district_list = []
for i in range(1,21):
    district = '750{}'.format(str(i).zfill(2))
    district_list.append(district)
print(district_list)
# Out:
# ['75001', '75002', '75003', '75004', '75005', '75006', '75007', '75008', '75009', '75010', '75011', '75012', '75013', '75014', '75015', '75016', '75017', '75018', '75019', '75020']

# %%
# Define a function to check if the address is within Paris
def in_paris(address):
    district_list = ['75001', '75002', '75003', '75004', '75005', '75006', '75007', '75008',
                     '75009', '75010', '75011', '75012', '75013', '75014', '75015', '75016',
                     '75017', '75018', '75019', '75020']
    for district in district_list:
        if district in address:
            return True
    return False

# %%
# Apply our function and take a look at our data
cinemas_final = cinemas_final[cinemas_final.address.apply(in_paris)]
cinemas_final = cinemas_final.reset_index(drop= True)
cinemas_final
# Out:
#                                  name  \
# 0              Luminor Hôtel de Ville
# 1                 Espace Saint-Michel
# 2                      Studio Galande
# 3             Centre Georges-Pompidou
# 4                Saint-André des Arts
# 5          MK2 Odéon (Côté St Michel)
# 6                       MK2 Beaubourg
# 7                        Christine 21
# 8     Le Champo - Espace Jacques Tati
# 9                        Nouvel Odéon
# 10                   Forum des images
# 11                          UGC Odéon
# 12                          Ecoles 21
# 13           UGC Ciné Cité Les Halles
# 14                     Reflet Medicis
# 15      Filmothèque du Quartier Latin
# 16                         UGC Danton
# 17        MK2 Odéon (Côté St Germain)
# 18                    Le Grand Action
# 19        Studio Luxembourg Accattone
# 20                   Les 3 Luxembourg
# 21                 Cinéma du Panthéon
# 22   MK2 Bastille (côté Beaumarchais)
# ...

# %% [markdown]
# Now our data only contains 80 cinemas within Paris, which is about right. Next step is to draw a map to check if our cinemas is in fact all in Paris

# %%
# This a the geolocation of Paris resulted from another search I did previously.
# I didn't include the code because it was similar to what we did in week 2 and week 3.
latitude = 48.8572082519531
longitude = 2.34143996238708

# %%
#create map of Paris using latitude and longitude
map_paris = folium.Map(location = [latitude, longitude], zoom_start = 12)

#add markers to the map
for name, add, lat, lng in zip(cinemas_final['name'],cinemas_final['address'], 
                               cinemas_final['latitude'],cinemas_final['longitude']):
    label = 'Cinema {} - {}'.format(name,add)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7
    ).add_to(map_paris)
    
map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As we can see, all the cinemas found are in Paris

# %% [markdown]
# ### 2.  Location of top 5 popular cinemas in Paris

# %% [markdown]
# We can find the list of popular cinemas in this website http://www.allocine.fr/salle/
# #### Next step
# We will try to scrap the name and address of these popular cinemas

# %%
# get the part of the website that contains data of the 10 most popular cinemas in France
url = 'http://www.allocine.fr/salle/'
source = requests.get(url)
soup = bs(source.text, 'lxml')
table = soup.find_all('table', class_="noborder")[0]
rows = table.find_all('tr')

# %%
# Extract from the data name, address
top_cinemas = []
for row in rows:
    row = row.text.strip().split('\n')
    name = row[-2]
    address = row[-1]
    
    # Only get the geolocation from popular cinemas in Paris
    if in_paris(address):
        lat,lon = get_lat_lon(address)
        popular_cine = {
            'name':name,
            'address':address,
            'latitude':lat,
            'longitude':lon
        }
        top_cinemas.append(popular_cine)
    # print out cinemas that are note in paris to double check
    else: 
        print(address, "NOT IN PARIS")
        continue
# Out:
# Le Dôme - Centre commercial Les 4 Temps 92092 Paris - La Défense NOT IN PARIS
# chemin des Pennes aux Pins 13170 Les Pennes-Mirabeau NOT IN PARIS
# 1 avenue de la Source de la Bievre 78180 Montigny-le-Bretonneux NOT IN PARIS
# Centre commercial Belle-Epine 94320 Thiais NOT IN PARIS
# 3 allée du préambule, Centre Commercial Carré Sénart 77127 Lieusaint NOT IN PARIS

# %%
df_top_cinemas = pd.DataFrame(top_cinemas, columns=['name','address','latitude','longitude'])
df_top_cinemas.to_csv('top_cinemas_in_paris.csv')
df_top_cinemas
# Out:
#                        name  \
# 0  UGC Ciné Cité Les Halles
# 1       UGC Ciné Cité Bercy
# 2          MK2 Bibliothèque
# 3              Pathé Wepler
# 4        Pathé Beaugrenelle
#
#                                              address   latitude  longitude
# 0  7, place de la Rotonde 75001 Paris 1er arrondi...  48.863190   2.342010
# 1  2, cour Saint-Emilion 75012 Paris 12e arrondis...  48.831835   2.385233
# 2  128-162 avenue de France 75013 Paris 13e arron...  48.831670   2.376000
# 3  140, bd de Clichy et 8, av de Clichy 75018 Par...  48.883940   2.328030
# 4        7 rue Linois 75015 Paris 15e arrondissement  48.848900   2.282580

# %% [markdown]
# ### 3. Geographic coordinates of 5 possible cinema addresses
# I will choose randomly 5 addresses out of all cinemas in Paris (except the top 5 popular ones) and pretend that those 5 address don't have cinema.
# Those 5 randomly choosen addresses will be possible locations to evaluate.

# %%
import random

# %%
possible_locations = []
num = 1 #create name for location

#randomly choose a integer from 0 to 79, then check if the cinemas with this index is in the top cinema list
#if not then give it a name and extract address, latitude and longitude
while len(possible_locations) < 5:
    i = random.randint(0,79)
    if cinemas_final.loc[i][0] not in list(df_top_cinemas.name):
        print(cinemas_final.loc[i,][0])
        location = {
            'location': 'L{}'.format(num),
            'address':cinemas_final.loc[i,].address,
            'latitude':cinemas_final.loc[i,].latitude,
            'longitude':cinemas_final.loc[i,].longitude
        }
        possible_locations.append(location)
        print('Found it', i)
        num += 1
# Out:
# MK2 Beaubourg
# Found it 6
# Gaumont Champs-Elysées - Marignan
# Found it 57
# UGC Opéra
# Found it 35
# UGC Ciné Cité Paris 19
# Found it 76
# Max Linder Panorama
# Found it 30

# %%
df_locations = pd.DataFrame(possible_locations, columns = ['location','address','latitude','longitude'] )
df_locations.to_csv('locations.csv')
df_locations
# Out:
#   location                                            address  latitude  \
# 0       L1    50, rue Rambuteau 75003 Paris 3e arrondissement  48.86158
# 1       L2  27-33 avenue des Champs-Elysées 75008 Paris 8e...  48.86946
# 2       L3  32, bd des Italiens 75009 Paris 9e arrondissement  48.87133
# 3       L4  166, boulevard Mac Donald 75019 Paris 19e arro...  48.89899
# 4       L5  24, bd Poissonniere 75009 Paris 9e arrondissement  48.87136
#
#    longitude
# 0    2.35229
# 1    2.30748
# 2    2.33530
# 3    2.37676
# 4    2.34489

# %% [markdown]
# ### 4. Eating, Shopping and Public transportation facility around cinema
# The recommended cinema location needs to have many eating and shopping venues and other entertainment nearby. Convenient public transport is also required.
# I can use FourSquare API to find these venues around the location.
#
# 3 minutes walking distance is about 200m. I think it is the suitable distance to search nearby venues.

# %% [markdown]
# #### Testing our method with the first cinema

# %%
print('Use the first cinema "{}" in the list as example to explore venues nearyby'.format(cinemas_final['name'][0]))
# Out:
# Use the first cinema "Luminor Hôtel de Ville" in the list as example to explore venues nearyby

# %% [markdown]
# Following categories will be used for finding the target venues. Full list of categories: https://developer.foursquare.com/docs/resources/categories

# %%
fs_categories = {
    'Food': '4d4b7105d754a06374d81259',
    'Shop & Service': '4d4b7105d754a06378d81259',
    'Bus Stop': '52f2ab2ebcbc57f1066b8b4f',
    'Metro Station': '4bf58dd8d48988d1fd931735',
    'Nightlife Spot': '4d4b7105d754a06376d81259',
    'Arts & Entertainment': '4d4b7104d754a06370d81259'
}

# %%
', '.join([ cat for cat in fs_categories])
# Out:
# 'Food, Shop & Service, Bus Stop, Metro Station, Nightlife Spot, Arts & Entertainment'

# %%
cinema = cinemas_final.loc[0]

# %%
#import dependencies
from six.moves.urllib import parse
from pandas.io.json import json_normalize

# %%
#set up search parameters using Foursquare API
CLIENT_ID = '<Your_client_id>'
CLIENT_SECRET = '<Your_secret_key>'
VERSION = '20181104'
LATITUDE,LONGITUDE = cinema['latitude'],cinema['longitude']
RADIUS = 200
CATID = '4d4b7105d754a06374d81259'
LIMIT = 50 #maximu venues returned by foursquare search venues methode

# %%
http = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'

# %%
url = http.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    LATITUDE,
    LONGITUDE,
    RADIUS,
    LIMIT,
    CATID
)
url

# %%
# Define a function to search nearby information and convert the result as dataframe
def venues_nearby(latitude, longitude, category, verbose=True):    
    url = http.format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        latitude,
        longitude,
        RADIUS,
        LIMIT,        
        fs_categories[category]
    )
    results = requests.get(url).json()['response']
    df = json_normalize(results['venues'])
    cols = ['name','latitude','longitude']    
    if( len(df) == 0 ):        
        df = pd.DataFrame(columns=cols)
    else:        
        df = df[['name','location.lat','location.lng']]
        df.columns = cols
    if( verbose ):
        print('{} "{}" venues are found within {}m of location'.format(len(df), category, RADIUS))
    return df

# %% [markdown]
# #### Find Metro Station around the cinema

# %%
venues_nearby(cinema['latitude'], cinema['longitude'], 'Metro Station').head()
# Out:
# 2 "Metro Station" venues are found within 300m of location
#                           name   latitude  longitude
# 0  Métro Hôtel de Ville [1,11]  48.857353   2.351761
# 1         Métro Rambuteau [11]  48.861298   2.353106

# %% [markdown]
# #### Find Bus Stop around the cinema

# %%
venues_nearby(cinema['latitude'], cinema['longitude'], 'Bus Stop').head()
# Out:
# 6 "Bus Stop" venues are found within 300m of location
#                                                 name   latitude  longitude
# 0                       Arrêt Hôtel de Ville [72,74]  48.856880   2.350751
# 1                             Arrêt La Verrerie [75]  48.857859   2.354724
# 2                 Arrêt Hôtel de Ville [67,69,76,96]  48.857162   2.352920
# 3  Arrêt Centre Georges Pompidou [38,47,75,N12,N1...  48.860359   2.352556
# 4                      Arrêt Archives–Rambuteau [29]  48.859697   2.357403

# %% [markdown]
# #### Find eating places around the cinema

# %%
venues_nearby(cinema['latitude'], cinema['longitude'], 'Food').head()
# Out:
# 50 "Food" venues are found within 200m of location
#                name   latitude  longitude
# 0  Café Voulez-Vous  48.858559   2.353403
# 1   Les Marronniers  48.857830   2.354573
# 2       Tata Burger  48.858945   2.353931
# 3        Caffè Vito  48.857731   2.354442
# 4        Grand Cœur  48.859737   2.353591

# %% [markdown]
# #### Find arts and entertainment places around the cinema

# %%
venues_nearby(cinema['latitude'], cinema['longitude'], 'Arts & Entertainment').head()
# Out:
# 50 "Arts & Entertainment" venues are found within 200m of location
#                                              name   latitude  longitude
# 0                          Luminor Hôtel de Ville  48.858654   2.353498
# 1  Centre Pompidou – Musée National d'Art Moderne  48.860445   2.352490
# 2                                       Le Renard  48.858204   2.351839
# 3                     Carpenters Workshop Gallery  48.858273   2.352852
# 4                         Galerie Bernard Ceysson  48.859418   2.352592

# %% [markdown]
# With above data, I can build a **content-based recommender systems** to resolve the problem.
#
# Combine with FourSquare API on counting how many different venues and Paris cinema list, a **cinema nearby venues matrix** can be built. The 5 popular cinema in Paris is the **profile** to combine with cinema nearby venues matrix to become a **weighted matrix of favorite cinema**.
#
# The weighted matrix can be applied on **5 possible locations with venues information** to generate a ranking result. The **the top one** on the ranking list can be recommended to my friend.

# %% [markdown]
# ## Section 3. Methodology

# %% [markdown]
# Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, and what machine learnings were used and why.

# %% [markdown]
# #### First, take a look at all the cinemas we found in the Data Section
# - cinemas in Paris are blue
# - top cinemas are red
# - possible location are yellow

# %%
#create map of Toronto using latitude and longitude
map_paris3 = folium.Map(location = [latitude, longitude], zoom_start = 12)

#add markers of all cinemas in Paris to the map
for name, add, lat, lng in zip(cinemas_final['name'],cinemas_final['address'], 
                               cinemas_final['latitude'],cinemas_final['longitude']):
    label = 'Cinema {} - {}'.format(name,add)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7
    ).add_to(map_paris3)

#add markers of 5 top cinemas in Paris to the map
for name, add, lat, lng in zip(df_top_cinemas['name'],df_top_cinemas['address'], 
                               df_top_cinemas['latitude'],df_top_cinemas['longitude']):
    label = 'Cinema {} - {}'.format(name,add)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup = label,
        color = 'red',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7
    ).add_to(map_paris3)

#add markers of 5 possible locations in Paris to the map    
for name, add, lat, lng in zip(df_locations['location'],df_locations['address'], 
                               df_locations['latitude'],df_locations['longitude']):
    label = 'Location {} - {}'.format(name,add)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat,lng],
        radius = 5,
        popup = label,
        color = 'yellow',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7
    ).add_to(map_paris3)
        
map_paris3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_paris3.save(outfile='paris_cinemas.html')

# %% [markdown]
# Now I can use the FourSquare API to explore nearby venues of Paris cinemas

# %%
from pathlib import Path

venues_csv = Path('./cinemas_venues.csv')
df_venues = None

# check the venues data is explored and downloaded 
if( venues_csv.exists() ):
    df_venues = pd.read_csv('./cinemas_venues.csv')
else:    
    # construct a dataframe to store data
    df_venues = pd.DataFrame(columns=['cinema_name', 'category', 'name', 'latitude', 'longitude'])
    # search nearby venues by category and by cinema
    for (name, address, latitude, longitude) in cinemas_final.itertuples(index=False):
        for cat, cat_id in fs_categories.items():
            df = venues_nearby(latitude, longitude, cat, verbose=False)
            df['cinema_name'] = name
            df['category'] = cat
            df_venues = df_venues.append(df, sort=True)
    df_venues.to_csv('cinemas_venues.csv', index=False)

# %%
print('Total {} of venues are found'.format(len(df_venues)))
# Out:
# Total 11528 of venues are found

# %%
# check the shape of data
df_venues.shape
# Out:
# (11528, 5)

# %%
# check some data
df_venues= pd.read_csv('cinemas_venues.csv', index_col = 0)
df_venues.head()
# Out:
#   category             cinema_name   latitude  longitude              name
# 0     Food  Luminor Hôtel de Ville  48.858559   2.353403  Café Voulez-Vous
# 1     Food  Luminor Hôtel de Ville  48.857830   2.354573   Les Marronniers
# 2     Food  Luminor Hôtel de Ville  48.858945   2.353931       Tata Burger
# 3     Food  Luminor Hôtel de Ville  48.857731   2.354442        Caffè Vito
# 4     Food  Luminor Hôtel de Ville  48.859737   2.353591        Grand Cœur

# %% [markdown]
# #### Number of venues in each category

# %%
df_venues['category'].value_counts().to_frame(name='count')
# Out:
#                       count
# Shop & Service         3745
# Food                   3742
# Nightlife Spot         2101
# Arts & Entertainment   1682
# Bus Stop                184
# Metro Station            74

# %% [markdown]
# #### Explore nearby venues of 5 possible/target locations

# %%
df_target_venues = pd.DataFrame(columns=['location', 'category', 'name', 'latitude', 'longitude'])
for (location, address, latitude, longitude) in df_locations.itertuples(index=False):
    for cat, cat_id in fs_categories.items():
        df = venues_nearby(latitude, longitude, cat, verbose=False)
        df['location'] = location
        df['category'] = cat
        df_target_venues = df_target_venues.append(df, sort=True)

# %%
df_target_venues.to_csv('target_venues.csv')
df_target_venues.head()
# Out:
#   category   latitude location  longitude                name
# 0     Food  48.861583       L1   2.352296        A l‘ancienne
# 1     Food  48.861626       L1   2.352668          Lapeyronie
# 2     Food  48.860915       L1   2.354640                Huré
# 3     Food  48.862301       L1   2.351142  Anticafé Beaubourg
# 4     Food  48.860018       L1   2.352059             Georges

# %% [markdown]
# #### Number of venues in each category

# %%
df_target_venues['category'].value_counts().to_frame(name='count')
# Out:
#                       count
# Food                    221
# Shop & Service          216
# Nightlife Spot          171
# Arts & Entertainment    141
# Bus Stop                  7
# Metro Station             5

# %%
df_target_venues.shape
# Out:
# (761, 5)

# %% [markdown]
# #### I only interested in number of venues in each category of dataframe.  So we will create dataframe containing only the number of venues in each category

# %%
#create dataframe containing only the number of venues in each category
df_venues_count = df_venues.groupby(['cinema_name','category'], as_index=False).count()
df_venues_count.drop(columns=['latitude','longitude'], inplace=True)
df_venues_count.rename(columns={'name':'count'}, inplace=True)
df_venues_count.head()
# Out:
#   cinema_name              category  count
# 0    Bretagne  Arts & Entertainment     15
# 1    Bretagne              Bus Stop      4
# 2    Bretagne                  Food     50
# 3    Bretagne        Nightlife Spot     24
# 4    Bretagne        Shop & Service     50

# %%
#transpose the data
df_venues_count = df_venues_count.pivot(index='cinema_name', columns='category', values='count').fillna(0)
df_venues_count.head()
# Out:
# category                 Arts & Entertainment  Bus Stop  Food  Metro Station  \
# cinema_name
# Bretagne                                 15.0       4.0  50.0            0.0
# CGR Paris Lilas                           4.0       3.0  16.0            1.0
# Centre Georges-Pompidou                  50.0       1.0  50.0            1.0
# Christine 21                             50.0       1.0  50.0            0.0
# Cinéma Chaplin Denfert                   12.0       2.0  50.0            1.0
#
# category                 Nightlife Spot  Shop & Service
# cinema_name
# Bretagne                           24.0            50.0
# CGR Paris Lilas                     2.0            20.0
# Centre Georges-Pompidou            50.0            50.0
# Christine 21                       45.0            50.0
# Cinéma Chaplin Denfert             11.0            50.0

# %%
# Do the same process on target locations
df_target_venues_count = df_target_venues.groupby(['location','category']).size().reset_index(name='count')
df_target_venues_count = df_target_venues_count.pivot(index='location', columns='category', values='count').fillna(0)
df_target_venues_count
# Out:
# category  Arts & Entertainment  Bus Stop  Food  Metro Station  Nightlife Spot  \
# location
# L1                        50.0       3.0  50.0            1.0            50.0
# L2                        19.0       1.0  50.0            1.0            50.0
# L3                        25.0       2.0  50.0            2.0            21.0
# L4                         2.0       0.0  21.0            0.0             0.0
# L5                        45.0       1.0  50.0            1.0            50.0
#
# category  Shop & Service
# location
# L1                  50.0
# L2                  50.0
# L3                  50.0
# L4                  16.0
# L5                  50.0

# %% [markdown]
# ### Data Analysis

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Check the data type of variables

# %%
df_venues_count.dtypes.to_frame(name='data_type')
# Out:
#                      data_type
# category
# Arts & Entertainment   float64
# Bus Stop               float64
# Food                   float64
# Metro Station          float64
# Nightlife Spot         float64
# Shop & Service         float64

# %% [markdown]
# All datatype is numeric

# %% [markdown]
# Generates descriptive statistics that summarize the central tendency,
# dispersion and shape of a dataset's distribution

# %%
df_venues_count.describe()
# Out:
# category  Arts & Entertainment   Bus Stop       Food  Metro Station  \
# count                80.000000  80.000000  80.000000      80.000000
# mean                 21.025000   2.300000  46.775000       0.925000
# std                  13.196638   1.408833   8.048862       0.651677
# min                   1.000000   0.000000  16.000000       0.000000
# 25%                  11.000000   1.000000  50.000000       1.000000
# 50%                  18.000000   2.000000  50.000000       1.000000
# 75%                  28.250000   3.000000  50.000000       1.000000
# max                  50.000000   7.000000  50.000000       3.000000
#
# category  Nightlife Spot  Shop & Service
# count          80.000000        80.00000
# mean           26.262500        46.81250
# std            16.973355         9.46826
# min             0.000000         7.00000
# 25%            11.000000        50.00000
# 50%            21.000000        50.00000
# 75%            45.250000        50.00000
# ...

# %% [markdown]
# - Cinema really has many 'Food', 'Shop & Service' venues around. There are cinemas that has 3 metro stations within 200 meters.
# - There are cinemas that has more than 50 "Arts & Entertainemnt", "Food", "Nightlife Spot" and "Shop & Service" venues and the number of these venues are capped by the limit of Foursquare search.

# %%
df_venues_count['Metro Station'].value_counts().sort_index().to_frame('Cinema Count')
# Out:
#      Cinema Count
# 0.0            19
# 1.0            49
# 2.0            11
# 3.0             1

# %% [markdown]
# One cinema contains 3 Metro Station within 200 meter radius

# %%
df_venues_count[df_venues_count['Metro Station'] > 2]
# Out:
# category                       Arts & Entertainment  Bus Stop  Food  \
# cinema_name
# Gaumont Opéra (côté Français)                  26.0       2.0  50.0
#
# category                       Metro Station  Nightlife Spot  Shop & Service
# cinema_name
# Gaumont Opéra (côté Français)            3.0            26.0            50.0

# %%
metro_over_2 = df_venues_count[df_venues_count['Metro Station'] > 2].index.tolist()
df_venues[(df_venues['cinema_name'].isin(metro_over_2)) & (df_venues.category == 'Metro Station')]
# Out:
#            category                    cinema_name   latitude  longitude  \
# 6306  Metro Station  Gaumont Opéra (côté Français)  48.870664   2.332288
# 6307  Metro Station  Gaumont Opéra (côté Français)  48.872908   2.333250
# 6308  Metro Station  Gaumont Opéra (côté Français)  48.869689   2.335883
#
#                                          name
# 6306                      Métro Opéra [3,7,8]
# 6307  Métro Chaussée d'Antin-La Fayette [7,9]
# 6308               Métro Quatre-Septembre [3]

# %% [markdown]
# ### Plot the distribution of other variables

# %%
f, axes = plt.subplots(2, 3, figsize=(15, 10))
sns.distplot(df_venues_count['Arts & Entertainment'] , color="skyblue", ax=axes[0, 0], kde=False)
sns.distplot(df_venues_count['Food'] , color="gold", ax=axes[0, 1], kde=False)
sns.distplot(df_venues_count['Shop & Service'] , color="teal", ax=axes[0, 2], kde=False)
sns.distplot(df_venues_count['Nightlife Spot'] , color="black", ax=axes[1, 0], kde=False)
sns.distplot(df_venues_count['Bus Stop'] , color="olive", ax=axes[1, 1], kde=False)
sns.distplot(df_venues_count['Metro Station'] , color="green", ax=axes[1, 2], kde=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ...

# %% [markdown]
# - "Arts and Entertainment" venues seem to have a normal distribution
# - We can see that "Food" and "Shop & Service" has a very similar distribution. This is due to the limit of venues returned by foursquare search and the fact that there are so many food and shop just within 200 meters of a cinema. Almost all cinemas has more than 50 of these venues within 200 meters.
# - Most of the Cinema has more than 50 "Nightlife Spot" venues with 200 meters radius.
# - The number of "Bus Stop" also seem to have a normal distribution
# - Most cinema has only 1 metro station in its 200 meters radius.

# %% [markdown]
# #### Check their **Pearson Correlation**

# %%
df_venues_count.corr()
# Out:
# category              Arts & Entertainment  Bus Stop      Food  Metro Station  \
# category
# Arts & Entertainment              1.000000  0.166399  0.487706       0.222477
# Bus Stop                          0.166399  1.000000  0.321939       0.383288
# Food                              0.487706  0.321939  1.000000       0.269441
# Metro Station                     0.222477  0.383288  0.269441       1.000000
# Nightlife Spot                    0.833299  0.319571  0.509209       0.282177
# Shop & Service                    0.412864  0.317424  0.808178       0.204893
#
# category              Nightlife Spot  Shop & Service
# category
# Arts & Entertainment        0.833299        0.412864
# Bus Stop                    0.319571        0.317424
# Food                        0.509209        0.808178
# Metro Station               0.282177        0.204893
# Nightlife Spot              1.000000        0.419972
# Shop & Service              0.419972        1.000000

# %% [markdown]
# It seems that 'Arts & Entertainment' and 'Nightlife Spot', 'Shop & Service' and 'Food' are highly correlated. Even though the number of these venues are capped by the limit of foursquare search. We can still see some correlation to some extent if we think of it as if a cinema have more than 50 venues or not.
#
# Find **P-Value** of the variables.

# %% [markdown]
# By convention, when the p-value is:
# - < 0.001 we say there is strong evidence that the correlation is significant,
# - < 0.05; there is moderate evidence that the correlation is significant,
# - < 0.1; there is weak evidence that the correlation is significant, and
# - is >  0.1; there is no evidence that the correlation is significant.

# %%
from scipy import stats

# %%
p_value_data = []
for left in df_venues_count.columns:
    p_values = [left]
    for right in df_venues_count.columns:        
        pearson_coef, p_value = stats.pearsonr(df_venues_count[left], df_venues_count[right])
        if(p_value < 0.001):
            p_values.append('strong')
        elif(p_value < 0.05):
            p_values.append('moderate')
        elif(p_value < 0.1):
            p_values.append('weak')
        else:
            p_values.append('no')            
    p_value_data.append(p_values)

# %%
df_p_values = pd.DataFrame(p_value_data, columns=['category'] + df_venues_count.columns.tolist())

# %%
df_p_values
# Out:
#                category Arts & Entertainment  Bus Stop      Food  \
# 0  Arts & Entertainment               strong        no    strong
# 1              Bus Stop                   no    strong  moderate
# 2                  Food               strong  moderate    strong
# 3         Metro Station             moderate    strong  moderate
# 4        Nightlife Spot               strong  moderate    strong
# 5        Shop & Service               strong  moderate    strong
#
#   Metro Station Nightlife Spot Shop & Service
# 0      moderate         strong         strong
# 1        strong       moderate       moderate
# 2      moderate         strong         strong
# 3        strong       moderate           weak
# 4      moderate         strong         strong
# 5          weak         strong         strong

# %% [markdown]
# The correlation between 'Bus Stop', 'Food', 'Metro Station' and 'Shop & Service' are statistically significant, and the coefficient of > 0.5 shows that the relationship is positive

# %% [markdown]
# ### Machine Learning

# %% [markdown]
# #### Rating the 5 most popular cinemas in Paris by me and my friend

# %%
rating_cinemas = [{'name': 'UGC Ciné Cité Les Halles', 'rating': 4.5},
 {'name': 'UGC Ciné Cité Bercy', 'rating': 4.5},
 {'name': 'MK2 Bibliothèque', 'rating': 4.3},
 {'name': 'Pathé Wepler', 'rating': 3.4},
 {'name': 'Pathé Beaugrenelle', 'rating': 3.1}]
rating_cinemas
# Out:
# [{'name': 'UGC Ciné Cité Les Halles', 'rating': 4.5},
#  {'name': 'UGC Ciné Cité Bercy', 'rating': 4.5},
#  {'name': 'MK2 Bibliothèque', 'rating': 4.3},
#  {'name': 'Pathé Wepler', 'rating': 3.4},
#  {'name': 'Pathé Beaugrenelle', 'rating': 3.1}]

# %%
df_rating = pd.DataFrame(rating_cinemas, columns=['name','rating'])
df_rating
# Out:
#                        name  rating
# 0  UGC Ciné Cité Les Halles     4.5
# 1       UGC Ciné Cité Bercy     4.5
# 2          MK2 Bibliothèque     4.3
# 3              Pathé Wepler     3.4
# 4        Pathé Beaugrenelle     3.1

# %% [markdown]
# #### Machine Learning

# %% [markdown]
# Now, let's use __Content-Based__ or __Item-Item recommendation systems__. In this case, I am going to try to figure out the top cinemas' location by counting number of nearby venues and ratings given.

# %% [markdown]
# Normalize the values of venues dataframe by using MinMaxScaler method

# %%
df_venues_count.head()
# Out:
# category                 Arts & Entertainment  Bus Stop  Food  Metro Station  \
# cinema_name
# Bretagne                                 15.0       4.0  50.0            0.0
# CGR Paris Lilas                           4.0       3.0  16.0            1.0
# Centre Georges-Pompidou                  50.0       1.0  50.0            1.0
# Christine 21                             50.0       1.0  50.0            0.0
# Cinéma Chaplin Denfert                   12.0       2.0  50.0            1.0
#
# category                 Nightlife Spot  Shop & Service
# cinema_name
# Bretagne                           24.0            50.0
# CGR Paris Lilas                     2.0            20.0
# Centre Georges-Pompidou            50.0            50.0
# Christine 21                       45.0            50.0
# Cinéma Chaplin Denfert             11.0            50.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
venues_normalized = scaler.fit_transform(df_venues_count)

# %%
df_venues_normalized = pd.DataFrame(
    venues_normalized,
    index=df_venues_count.index,
    columns=df_venues_count.columns
)

# %%
df_venues_normalized.head()
# Out:
# category                 Arts & Entertainment  Bus Stop  Food  Metro Station  \
# cinema_name
# Bretagne                             0.285714  0.571429   1.0       0.000000
# CGR Paris Lilas                      0.061224  0.428571   0.0       0.333333
# Centre Georges-Pompidou              1.000000  0.142857   1.0       0.333333
# Christine 21                         1.000000  0.142857   1.0       0.000000
# Cinéma Chaplin Denfert               0.224490  0.285714   1.0       0.333333
#
# category                 Nightlife Spot  Shop & Service
# cinema_name
# Bretagne                           0.48        1.000000
# CGR Paris Lilas                    0.04        0.302326
# Centre Georges-Pompidou            1.00        1.000000
# Christine 21                       0.90        1.000000
# Cinéma Chaplin Denfert             0.22        1.000000

# %% [markdown]
# Merge the data with the top cinamas rating list

# %%
top_rating_table = pd.merge(
    df_rating,
    df_venues_normalized,
    how='inner',
    left_on='name',
    right_index=True
)
top_rating_table.drop(['name','rating'], axis=1, inplace=True)
top_rating_table
# Out:
#    Arts & Entertainment  Bus Stop      Food  Metro Station  Nightlife Spot  \
# 0              0.918367  0.142857  1.000000       0.000000            0.94
# 1              0.040816  0.142857  0.352941       0.333333            0.14
# 2              0.265306  0.428571  1.000000       0.333333            0.18
# 3              0.367347  0.428571  1.000000       0.333333            0.94
# 4              0.204082  0.142857  0.852941       0.000000            0.16
#
#    Shop & Service
# 0        1.000000
# 1        0.697674
# 2        0.744186
# 3        1.000000
# 4        1.000000

# %% [markdown]
# Dot product to get the weight of rating on each category according to boss's favorite

# %%
top_cinemas_profile = top_rating_table.transpose().dot(df_rating['rating'])

# %%
top_cinemas_profile
# Out:
# Arts & Entertainment     7.338776
# Bus Stop                 5.028571
# Food                    16.432353
# Metro Station            4.066667
# Nightlife Spot           9.326000
# Shop & Service          17.339535
# dtype: float64

# %% [markdown]
# Normalize the values of venues around the target location

# %%
df_targets_normalized = pd.DataFrame(
    scaler.transform(df_target_venues_count),
    index=df_target_venues_count.index,
    columns=df_target_venues_count.columns
)

# %%
df_targets_normalized
# Out:
# category  Arts & Entertainment  Bus Stop      Food  Metro Station  \
# location
# L1                    1.000000  0.428571  1.000000       0.333333
# L2                    0.367347  0.142857  1.000000       0.333333
# L3                    0.489796  0.285714  1.000000       0.666667
# L4                    0.020408  0.000000  0.147059       0.000000
# L5                    0.897959  0.142857  1.000000       0.333333
#
# category  Nightlife Spot  Shop & Service
# location
# L1                  1.00        1.000000
# L2                  1.00        1.000000
# L3                  0.42        1.000000
# L4                  0.00        0.209302
# L5                  1.00        1.000000

# %% [markdown]
# ## Section 4. Results

# %% [markdown]
# Results section where you discuss the results.

# %% [markdown]
# With the profile of top cinemas and the complete list of cinemas and their venues count in hand, I am going to take the weighted average of every lcoation based on the profile and recommend the top location that most satisfy it.

# %%
df_recommend = (df_targets_normalized*top_cinemas_profile).sum(axis=1)/top_cinemas_profile.sum()
df_recommend = df_recommend.reset_index(name='rating')

# %%
df_locations
# Out:
#   location                                            address  latitude  \
# 0       L1    50, rue Rambuteau 75003 Paris 3e arrondissement  48.86158
# 1       L2  27-33 avenue des Champs-Elysées 75008 Paris 8e...  48.86946
# 2       L3  32, bd des Italiens 75009 Paris 9e arrondissement  48.87133
# 3       L4  166, boulevard Mac Donald 75019 Paris 19e arro...  48.89899
# 4       L5  24, bd Poissonniere 75009 Paris 9e arrondissement  48.87136
#
#    longitude
# 0    2.35229
# 1    2.30748
# 2    2.33530
# 3    2.37676
# 4    2.34489

# %%
df_final = pd.merge(
    df_locations,
    df_recommend,
    left_on='location',
    right_on='location'
)
df_final.sort_values('rating', ascending=False, inplace=True)

# %%
df_final
# Out:
#   location                                            address  latitude  \
# 0       L1    50, rue Rambuteau 75003 Paris 3e arrondissement  48.86158
# 4       L5  24, bd Poissonniere 75009 Paris 9e arrondissement  48.87136
# 1       L2  27-33 avenue des Champs-Elysées 75008 Paris 8e...  48.86946
# 2       L3  32, bd des Italiens 75009 Paris 9e arrondissement  48.87133
# 3       L4  166, boulevard Mac Donald 75019 Paris 19e arro...  48.89899
#
#    longitude    rating
# 0    2.35229  0.906192
# 4    2.34489  0.869479
# 1    2.30748  0.804068
# 2    2.33530  0.763140
# 3    2.37676  0.104070

# %%
print('I should recommend the location "{}" of address "{}" to the stackholder'.format(df_final.iat[0,0], df_final.iat[0,1]))
# Out:
# I should recommend the location "L1" of address "50, rue Rambuteau 75003 Paris 3e arrondissement" to the stackholder

# %% [markdown]
# The result is reasonable. Location "L1" has the most number of venues in all categories.

# %%
df_target_venues_count.head()
# Out:
# category  Arts & Entertainment  Bus Stop  Food  Metro Station  Nightlife Spot  \
# location
# L1                        50.0       3.0  50.0            1.0            50.0
# L2                        19.0       1.0  50.0            1.0            50.0
# L3                        25.0       2.0  50.0            2.0            21.0
# L4                         2.0       0.0  21.0            0.0             0.0
# L5                        45.0       1.0  50.0            1.0            50.0
#
# category  Shop & Service
# location
# L1                  50.0
# L2                  50.0
# L3                  50.0
# L4                  16.0
# L5                  50.0

# %% [markdown]
# The categories are most concerned according to profile rating

# %%
top_cinemas_profile.sort_values(ascending=False)
# Out:
# Shop & Service          17.339535
# Food                    16.432353
# Nightlife Spot           9.326000
# Arts & Entertainment     7.338776
# Bus Stop                 5.028571
# Metro Station            4.066667
# dtype: float64

# %% [markdown]
# Therefore, Location "L1" should be recommeded to my friend

# %% [markdown]
# ## Section 5. Discussion

# %% [markdown]
# Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.

# %% [markdown]
# - 50 is the limit of venues return by search venues method provided by Foursquare. It's remarkable when we can easily find 50 venues of food places, shopping and nightlift spots within 200 meters around the cinemas. This can show us how lively Paris is.
# - This also show us how popular Foursquare is in Paris since all these venues are collected by check-ins of users. This can be due to the fact that Paris is big touristic city. People from all around the world come to visit and check-in to share it with their friends.
# - If we can somehow remove the limitation of venues returned by foursquare search method, our result can become even more accurate. However, this will certainly become more expensive and I don't have the mean to do this.

# %% [markdown]
# Although some of the data are still partially fictive. We have come up with a way to solve the business problem of finding the most suitable location to open a cinema. In order to apply this in real life, we need to improve several things:
# - Increase the radius of search venues since when people go out, they can go for more than 200 meters to find a place to hang out.
# - Remove the limitation of search venues returned by Foursquare, doing this remove the cap of our data, hence improve greatly the accuracy.
# - This approach still using fiction locations which are randomly chosen from already establish cinemas in Paris.
# - The rating of top cinemas in Paris are based totally on subjective preference of my friend and I. Performing a survey to rate the top 5 cinemas is a good way to accurately rate and produce a good profile for top cinemas.

# %% [markdown]
# ## Section 6.Conclusion

# %% [markdown]
# Conclusion section where you conclude the report.

# %% [markdown]
# My friend's business problem is resolved. He wants to find the best place to build a new cinema in Paris , and the factors of "best location" is based on the number of venues in eating, shopping, transportation category around the location. Content-based filtering machine learning technique is the most suitable method to resolve the problem. It uses my friend and I's preference of top cinemas  to make the recommendation result.
#
# Since we randomly pick the 5 target locations of cinema in Paris as our possible locations, these 5 locations won't be used in reality. However, we can later pick 5 REAL locations to start. As the weighting matrix is developed, the recommendation becomes easy to redo again.
